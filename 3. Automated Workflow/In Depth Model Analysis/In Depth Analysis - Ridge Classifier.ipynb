# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.linear_model import RidgeClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(RidgeClassifier(),
                 dict(alpha = np.arange(0.1, 5, 0.5),
                      fit_intercept = [True, False],
                      normalize = [True, False],
                      solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']),
                 cv = skf,
                 scoring = my_custom_score),    
]           
                 
                 
iterations = 10                
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(RidgeClassifier(),
                 dict(),
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished RidgeClassifier with No Scaling and 1 features after 19.23 seconds
# Finished RidgeClassifier with No Scaling and 2 features after 22.02 seconds
# Finished RidgeClassifier with No Scaling and 3 features after 113.84 seconds
# Finished RidgeClassifier with No Scaling and 4 features after 115.81 seconds
# Finished RidgeClassifier with No Scaling and 5 features after 114.03 seconds
# Finished RidgeClassifier with No Scaling and 6 features after 112.13 seconds
# Finished RidgeClassifier with No Scaling and 7 features after 117.07 seconds
# Finished RidgeClassifier with No Scaling and 8 features after 113.65 seconds
# Finished RidgeClassifier with No Scaling and 9 features after 220.39 seconds
# Finished RidgeClassifier with No Scaling and 10 features after 240.59 seconds
# Finished RidgeClassifier with No Scaling and 11 features after 225.82 seconds
# Finished RidgeClassifier with No Scaling and 12 features after 218.51 seconds
# Finished RidgeClassifier with No Scaling and 13 features after 265.2 seconds
# Finished RidgeClassifier with No Scaling and 14 features after 268.45 seconds
# Finished RidgeClassifier with No Scaling and 15 features after 277.87 seconds
# Finished RidgeClassifier with No Scaling and 16 features after 145.61 seconds
# Finished RidgeClassifier with No Scaling and 17 features after 144.85 seconds
# Finished RidgeClassifier with No Scaling and 18 features after 146.89 seconds
# Finished RidgeClassifier with No Scaling and 19 features after 252.95 seconds
# Finished RidgeClassifier with No Scaling and 20 features after 269.37 seconds
# Finished RidgeClassifier with MinMaxScaler and 1 features after 26.16 seconds
# Finished RidgeClassifier with MinMaxScaler and 2 features after 28.74 seconds
# Finished RidgeClassifier with MinMaxScaler and 3 features after 182.97 seconds
# Finished RidgeClassifier with MinMaxScaler and 4 features after 196.62 seconds
# Finished RidgeClassifier with MinMaxScaler and 5 features after 176.74 seconds
# Finished RidgeClassifier with MinMaxScaler and 6 features after 138.35 seconds
# Finished RidgeClassifier with MinMaxScaler and 7 features after 133.09 seconds
# Finished RidgeClassifier with MinMaxScaler and 8 features after 136.78 seconds
# Finished RidgeClassifier with MinMaxScaler and 9 features after 137.92 seconds
# Finished RidgeClassifier with MinMaxScaler and 10 features after 140.54 seconds
# Finished RidgeClassifier with MinMaxScaler and 11 features after 145.11 seconds
# Finished RidgeClassifier with MinMaxScaler and 12 features after 149.99 seconds
# Finished RidgeClassifier with MinMaxScaler and 13 features after 155.74 seconds
# Finished RidgeClassifier with MinMaxScaler and 14 features after 163.85 seconds
# Finished RidgeClassifier with MinMaxScaler and 15 features after 210.14 seconds
# Finished RidgeClassifier with MinMaxScaler and 16 features after 101.8 seconds
# Finished RidgeClassifier with MinMaxScaler and 17 features after 104.79 seconds
# Finished RidgeClassifier with MinMaxScaler and 18 features after 107.97 seconds
# Finished RidgeClassifier with MinMaxScaler and 19 features after 183.74 seconds
# Finished RidgeClassifier with MinMaxScaler and 20 features after 184.04 seconds
# Finished RidgeClassifier with StandardScaler and 1 features after 14.53 seconds
# Finished RidgeClassifier with StandardScaler and 2 features after 15.59 seconds
# Finished RidgeClassifier with StandardScaler and 3 features after 93.07 seconds
# Finished RidgeClassifier with StandardScaler and 4 features after 98.27 seconds
# Finished RidgeClassifier with StandardScaler and 5 features after 102.53 seconds
# Finished RidgeClassifier with StandardScaler and 6 features after 104.64 seconds
# Finished RidgeClassifier with StandardScaler and 7 features after 110.03 seconds
# Finished RidgeClassifier with StandardScaler and 8 features after 110.58 seconds
# Finished RidgeClassifier with StandardScaler and 9 features after 113.76 seconds
# Finished RidgeClassifier with StandardScaler and 10 features after 118.63 seconds
# Finished RidgeClassifier with StandardScaler and 11 features after 121.38 seconds
# Finished RidgeClassifier with StandardScaler and 12 features after 125.03 seconds
# Finished RidgeClassifier with StandardScaler and 13 features after 128.06 seconds
# Finished RidgeClassifier with StandardScaler and 14 features after 131.63 seconds
# Finished RidgeClassifier with StandardScaler and 15 features after 143.34 seconds
# Finished RidgeClassifier with StandardScaler and 16 features after 75.72 seconds
# Finished RidgeClassifier with StandardScaler and 17 features after 82.71 seconds
# Finished RidgeClassifier with StandardScaler and 18 features after 85.55 seconds
# Finished RidgeClassifier with StandardScaler and 19 features after 146.4 seconds
# Finished RidgeClassifier with StandardScaler and 20 features after 149.46 seconds
# Finished RidgeClassifier with LogScaler and 1 features after 15.08 seconds
# Finished RidgeClassifier with LogScaler and 2 features after 16.45 seconds
# Finished RidgeClassifier with LogScaler and 3 features after 16.92 seconds
# Finished RidgeClassifier with LogScaler and 4 features after 27.65 seconds
# Finished RidgeClassifier with LogScaler and 5 features after 26.7 seconds
# Finished RidgeClassifier with LogScaler and 6 features after 25.54 seconds
# Finished RidgeClassifier with LogScaler and 7 features after 112.19 seconds
# Finished RidgeClassifier with LogScaler and 8 features after 59.6 seconds
# Finished RidgeClassifier with LogScaler and 9 features after 61.3 seconds
# Finished RidgeClassifier with LogScaler and 10 features after 63.06 seconds
# Finished RidgeClassifier with LogScaler and 11 features after 64.27 seconds
# Finished RidgeClassifier with LogScaler and 12 features after 65.96 seconds
# Finished RidgeClassifier with LogScaler and 13 features after 67.87 seconds
# Finished RidgeClassifier with LogScaler and 14 features after 69.1 seconds
# Finished RidgeClassifier with LogScaler and 15 features after 75.34 seconds
# Finished RidgeClassifier with LogScaler and 16 features after 77.99 seconds
# Finished RidgeClassifier with LogScaler and 17 features after 78.15 seconds
# Finished RidgeClassifier with LogScaler and 18 features after 78.82 seconds
# Finished RidgeClassifier with LogScaler and 19 features after 141.45 seconds
# Finished RidgeClassifier with LogScaler and 20 features after 147.71 seconds
#               Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 0   RidgeClassifier       No Scaling             1                                       [trustLevel]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 1   RidgeClassifier       No Scaling             2                     [trustLevel, scannedLineItems]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 58  RidgeClassifier   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 57  RidgeClassifier   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 56  RidgeClassifier   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 55  RidgeClassifier   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 54  RidgeClassifier   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 53  RidgeClassifier   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 52  RidgeClassifier   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 51  RidgeClassifier   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 50  RidgeClassifier   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 49  RidgeClassifier   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 48  RidgeClassifier   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 47  RidgeClassifier   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 46  RidgeClassifier   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 45  RidgeClassifier   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 44  RidgeClassifier   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 43  RidgeClassifier   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 42  RidgeClassifier   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 59  RidgeClassifier   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 60  RidgeClassifier        LogScaler             1                                       [trustLevel]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 61  RidgeClassifier        LogScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 71  RidgeClassifier        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 78  RidgeClassifier        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 77  RidgeClassifier        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 76  RidgeClassifier        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 75  RidgeClassifier        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 74  RidgeClassifier        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 73  RidgeClassifier        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 72  RidgeClassifier        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 70  RidgeClassifier        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 62  RidgeClassifier        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 69  RidgeClassifier        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 68  RidgeClassifier        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 67  RidgeClassifier        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 66  RidgeClassifier        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 65  RidgeClassifier        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 64  RidgeClassifier        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 63  RidgeClassifier        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 41  RidgeClassifier   StandardScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 40  RidgeClassifier   StandardScaler             1                                       [trustLevel]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 39  RidgeClassifier     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 10  RidgeClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 17  RidgeClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 16  RidgeClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 15  RidgeClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 14  RidgeClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 13  RidgeClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 12  RidgeClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 11  RidgeClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 9   RidgeClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 19  RidgeClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 8   RidgeClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 7   RidgeClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 6   RidgeClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 5   RidgeClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 4   RidgeClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 3   RidgeClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 2   RidgeClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 18  RidgeClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 20  RidgeClassifier     MinMaxScaler             1                                       [trustLevel]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 38  RidgeClassifier     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 30  RidgeClassifier     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 37  RidgeClassifier     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 36  RidgeClassifier     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 35  RidgeClassifier     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 34  RidgeClassifier     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 33  RidgeClassifier     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 32  RidgeClassifier     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 31  RidgeClassifier     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 29  RidgeClassifier     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 21  RidgeClassifier     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 28  RidgeClassifier     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 27  RidgeClassifier     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 26  RidgeClassifier     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 25  RidgeClassifier     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 24  RidgeClassifier     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 23  RidgeClassifier     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 22  RidgeClassifier     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest
# 79  RidgeClassifier        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.1, 'fit_intercept': True, 'normali...                           -0.276743                                          0.011709  RidgeClassifier(alpha=0.1, class_weight=None, ...                 SelectKBest

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)

# %%
#result_table.to_pickle("result_table_RidgeClassifier.pkl")
result_table = pd.read_pickle("result_table_RidgeClassifier.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='auto',
#         tol=0.001)
# ['trustLevel']
# {}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  104
# True positive:  0
# -520 for 1879 instances in the test set
# -0.2767429483767962 per instance in the test set
