# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.tree import ExtraTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble.forest import ExtraTreesClassifier
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble.bagging import BaggingClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(BaggingClassifier(),
                 dict(n_estimators = [5, 10, 20, 50, 100, 150, 200],
                      base_estimator = [DecisionTreeClassifier(max_depth=1), # default setting for AdaBoost
                                        LogisticRegression(),
                                        ExtraTreesClassifier(),
                              #          GradientBoostingClassifier(), # takes a long time (-> + 30 sec)
                              #          RandomForestClassifier(),  # takes a long time (-> + 30 sec)
                                        DecisionTreeClassifier(),
                                        ExtraTreeClassifier(),
                                        None]),   # standard -> 'Decision Tree'
                 cv = skf,
                 scoring = my_custom_score,
                n_jobs = -1)
]           
                 
                 
iterations = 100                 
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(BaggingClassifier(),
                 dict(n_estimators = [5, 10, 20, 50, 100, 150, 200],
                      base_estimator = [DecisionTreeClassifier(max_depth=1), # default setting for AdaBoost
                                        LogisticRegression(),
                                        ExtraTreesClassifier(),
                              #          GradientBoostingClassifier(), # takes a long time (-> + 30 sec)
                              #          RandomForestClassifier(),  # takes a long time (-> + 30 sec)
                                        DecisionTreeClassifier(),
                                        ExtraTreeClassifier(),
                                        None]),   # standard -> 'Decision Tree'
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations,
                      n_jobs = -1)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Feature Selection Technique", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished BaggingClassifier with No Scaling and 1 features after 32.51 seconds
# Finished BaggingClassifier with No Scaling and 2 features after 35.44 seconds
# Finished BaggingClassifier with No Scaling and 3 features after 39.53 seconds
# Finished BaggingClassifier with No Scaling and 4 features after 22.03 seconds
# Finished BaggingClassifier with No Scaling and 5 features after 34.89 seconds
# Finished BaggingClassifier with No Scaling and 6 features after 30.8 seconds
# Finished BaggingClassifier with No Scaling and 7 features after 52.02 seconds
# Finished BaggingClassifier with No Scaling and 8 features after 42.84 seconds
# Finished BaggingClassifier with No Scaling and 9 features after 40.44 seconds
# Finished BaggingClassifier with No Scaling and 10 features after 49.6 seconds
# Finished BaggingClassifier with No Scaling and 11 features after 45.13 seconds
# Finished BaggingClassifier with No Scaling and 12 features after 67.67 seconds
# Finished BaggingClassifier with No Scaling and 13 features after 47.71 seconds
# Finished BaggingClassifier with No Scaling and 14 features after 39.97 seconds
# Finished BaggingClassifier with No Scaling and 15 features after 43.26 seconds
# Finished BaggingClassifier with No Scaling and 16 features after 49.45 seconds
# Finished BaggingClassifier with No Scaling and 17 features after 48.39 seconds
# Finished BaggingClassifier with No Scaling and 18 features after 49.63 seconds
# Finished BaggingClassifier with No Scaling and 19 features after 53.71 seconds
# Finished BaggingClassifier with No Scaling and 20 features after 44.06 seconds
# Finished BaggingClassifier with MinMaxScaler and 1 features after 41.83 seconds
# Finished BaggingClassifier with MinMaxScaler and 2 features after 35.71 seconds
# Finished BaggingClassifier with MinMaxScaler and 3 features after 50.0 seconds
# Finished BaggingClassifier with MinMaxScaler and 4 features after 42.2 seconds
# Finished BaggingClassifier with MinMaxScaler and 5 features after 40.59 seconds
# Finished BaggingClassifier with MinMaxScaler and 6 features after 61.45 seconds
# Finished BaggingClassifier with MinMaxScaler and 7 features after 48.01 seconds
# Finished BaggingClassifier with MinMaxScaler and 8 features after 30.44 seconds
# Finished BaggingClassifier with MinMaxScaler and 9 features after 39.72 seconds
# Finished BaggingClassifier with MinMaxScaler and 10 features after 60.1 seconds
# Finished BaggingClassifier with MinMaxScaler and 11 features after 44.06 seconds
# Finished BaggingClassifier with MinMaxScaler and 12 features after 46.43 seconds
# Finished BaggingClassifier with MinMaxScaler and 13 features after 39.28 seconds
# Finished BaggingClassifier with MinMaxScaler and 14 features after 29.43 seconds
# Finished BaggingClassifier with MinMaxScaler and 15 features after 48.53 seconds
# Finished BaggingClassifier with MinMaxScaler and 16 features after 52.64 seconds
# Finished BaggingClassifier with MinMaxScaler and 17 features after 67.67 seconds
# Finished BaggingClassifier with MinMaxScaler and 18 features after 52.98 seconds
# Finished BaggingClassifier with MinMaxScaler and 19 features after 51.68 seconds
# Finished BaggingClassifier with MinMaxScaler and 20 features after 52.62 seconds
# Finished BaggingClassifier with StandardScaler and 1 features after 47.42 seconds
# Finished BaggingClassifier with StandardScaler and 2 features after 31.87 seconds
# Finished BaggingClassifier with StandardScaler and 3 features after 60.27 seconds
# Finished BaggingClassifier with StandardScaler and 4 features after 43.34 seconds
# Finished BaggingClassifier with StandardScaler and 5 features after 41.77 seconds
# Finished BaggingClassifier with StandardScaler and 6 features after 34.17 seconds
# Finished BaggingClassifier with StandardScaler and 7 features after 33.63 seconds
# Finished BaggingClassifier with StandardScaler and 8 features after 37.53 seconds
# Finished BaggingClassifier with StandardScaler and 9 features after 32.7 seconds
# Finished BaggingClassifier with StandardScaler and 10 features after 59.71 seconds
# Finished BaggingClassifier with StandardScaler and 11 features after 58.45 seconds
# Finished BaggingClassifier with StandardScaler and 12 features after 45.12 seconds
# Finished BaggingClassifier with StandardScaler and 13 features after 42.36 seconds
# Finished BaggingClassifier with StandardScaler and 14 features after 38.1 seconds
# Finished BaggingClassifier with StandardScaler and 15 features after 48.04 seconds
# Finished BaggingClassifier with StandardScaler and 16 features after 39.31 seconds
# Finished BaggingClassifier with StandardScaler and 17 features after 66.52 seconds
# Finished BaggingClassifier with StandardScaler and 18 features after 57.96 seconds
# Finished BaggingClassifier with StandardScaler and 19 features after 36.77 seconds
# Finished BaggingClassifier with StandardScaler and 20 features after 44.46 seconds
# Finished BaggingClassifier with LogScaler and 1 features after 27.95 seconds
# Finished BaggingClassifier with LogScaler and 2 features after 21.14 seconds
# Finished BaggingClassifier with LogScaler and 3 features after 19.95 seconds
# Finished BaggingClassifier with LogScaler and 4 features after 21.89 seconds
# Finished BaggingClassifier with LogScaler and 5 features after 34.55 seconds
# Finished BaggingClassifier with LogScaler and 6 features after 30.77 seconds
# Finished BaggingClassifier with LogScaler and 7 features after 24.6 seconds
# Finished BaggingClassifier with LogScaler and 8 features after 25.5 seconds
# Finished BaggingClassifier with LogScaler and 9 features after 33.99 seconds
# Finished BaggingClassifier with LogScaler and 10 features after 33.94 seconds
# Finished BaggingClassifier with LogScaler and 11 features after 33.72 seconds
# Finished BaggingClassifier with LogScaler and 12 features after 40.5 seconds
# Finished BaggingClassifier with LogScaler and 13 features after 45.73 seconds
# Finished BaggingClassifier with LogScaler and 14 features after 34.94 seconds
# Finished BaggingClassifier with LogScaler and 15 features after 45.07 seconds
# Finished BaggingClassifier with LogScaler and 16 features after 32.92 seconds
# Finished BaggingClassifier with LogScaler and 17 features after 36.43 seconds
# Finished BaggingClassifier with LogScaler and 18 features after 39.84 seconds
# Finished BaggingClassifier with LogScaler and 19 features after 36.87 seconds
# Finished BaggingClassifier with LogScaler and 20 features after 45.61 seconds
#                 Model Data Preparation Feature Count Feature Selection Technique                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 70  BaggingClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.114423                                          0.077750  (ExtraTreeClassifier(class_weight=None, criter...
# 51  BaggingClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.106440                                          0.085583  ((ExtraTreeClassifier(class_weight=None, crite...
# 7   BaggingClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.103779                                          0.098962  ((ExtraTreeClassifier(class_weight=None, crite...
# 35  BaggingClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.101118                                          0.090247  ((ExtraTreeClassifier(class_weight=None, crite...
# 29  BaggingClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.101118                                          0.074764  (ExtraTreeClassifier(class_weight=None, criter...
# 11  BaggingClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.101118                                          0.064778  (ExtraTreeClassifier(class_weight=None, criter...
# 49  BaggingClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.101118                                          0.085315  ((ExtraTreeClassifier(class_weight=None, crite...
# 28  BaggingClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.098457                                          0.094317  (ExtraTreeClassifier(class_weight=None, criter...
# 31  BaggingClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.098457                                          0.078702  (ExtraTreeClassifier(class_weight=None, criter...
# 71  BaggingClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.095796                                          0.070299  ((ExtraTreeClassifier(class_weight=None, crite...
# 10  BaggingClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.093135                                          0.078099  (ExtraTreeClassifier(class_weight=None, criter...
# 9   BaggingClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.093135                                          0.104323  ((ExtraTreeClassifier(class_weight=None, crite...
# 52  BaggingClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.093135                                          0.084187  (ExtraTreeClassifier(class_weight=None, criter...
# 48  BaggingClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.090474                                          0.082440  ((ExtraTreeClassifier(class_weight=None, crite...
# 33  BaggingClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.087813                                          0.079756  ((ExtraTreeClassifier(class_weight=None, crite...
# 47  BaggingClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.087813                                          0.070239  ((ExtraTreeClassifier(class_weight=None, crite...
# 55  BaggingClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.087813                                          0.086477  (ExtraTreeClassifier(class_weight=None, criter...
# 72  BaggingClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.087813                                          0.083230  ((ExtraTreeClassifier(class_weight=None, crite...
# 69  BaggingClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.085152                                          0.109996  ((ExtraTreeClassifier(class_weight=None, crite...
# 30  BaggingClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.085152                                          0.102680  ((ExtraTreeClassifier(class_weight=None, crite...
# 50  BaggingClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.082491                                          0.090748  ((ExtraTreeClassifier(class_weight=None, crite...
# 32  BaggingClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.082491                                          0.080084  (ExtraTreeClassifier(class_weight=None, criter...
# 16  BaggingClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.079830                                          0.076013  (ExtraTreeClassifier(class_weight=None, criter...
# 8   BaggingClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.079830                                          0.098771  (ExtraTreeClassifier(class_weight=None, criter...
# 6   BaggingClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.079830                                          0.107653  (ExtraTreeClassifier(class_weight=None, criter...
# 27  BaggingClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.079830                                          0.086517  ((ExtraTreeClassifier(class_weight=None, crite...
# 66  BaggingClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.074508                                          0.091870  (ExtraTreeClassifier(class_weight=None, criter...
# 15  BaggingClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.074508                                          0.081199  (ExtraTreeClassifier(class_weight=None, criter...
# 78  BaggingClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.071847                                          0.089267  (LogisticRegression(C=1.0, class_weight=None, ...
# 13  BaggingClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.071847                                          0.065164  ((ExtraTreeClassifier(class_weight=None, crite...
# 73  BaggingClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.071847                                          0.081556  ((ExtraTreeClassifier(class_weight=None, crite...
# 17  BaggingClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.069186                                          0.096776  ((ExtraTreeClassifier(class_weight=None, crite...
# 14  BaggingClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.069186                                          0.089092  ((ExtraTreeClassifier(class_weight=None, crite...
# 53  BaggingClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.066525                                          0.124346  (ExtraTreeClassifier(class_weight=None, criter...
# 77  BaggingClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.093834  ((ExtraTreeClassifier(class_weight=None, crite...
# 68  BaggingClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.066525                                          0.124227  (ExtraTreeClassifier(class_weight=None, criter...
# 76  BaggingClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.104399  ((ExtraTreeClassifier(class_weight=None, crite...
# 12  BaggingClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.098827  ((ExtraTreeClassifier(class_weight=None, crite...
# 75  BaggingClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.084990  ((ExtraTreeClassifier(class_weight=None, crite...
# 56  BaggingClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.063864                                          0.076502  (LogisticRegression(C=1.0, class_weight=None, ...
# 46  BaggingClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.063864                                          0.130749  (ExtraTreeClassifier(class_weight=None, criter...
# 34  BaggingClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.063864                                          0.094499  (ExtraTreeClassifier(class_weight=None, criter...
# 36  BaggingClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.063864                                          0.074376  ((ExtraTreeClassifier(class_weight=None, crite...
# 38  BaggingClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.061203                                          0.085797  ((ExtraTreeClassifier(class_weight=None, crite...
# 67  BaggingClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.058542                                          0.056677  (ExtraTreeClassifier(class_weight=None, criter...
# 74  BaggingClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.055881                                          0.065524  (ExtraTreeClassifier(class_weight=None, criter...
# 58  BaggingClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.055881                                          0.081955  ((ExtraTreeClassifier(class_weight=None, crite...
# 37  BaggingClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.053220                                          0.077087  ((ExtraTreeClassifier(class_weight=None, crite...
# 59  BaggingClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.050559                                          0.105520  (LogisticRegression(C=1.0, class_weight=None, ...
# 18  BaggingClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.050559                                          0.111993  (LogisticRegression(C=1.0, class_weight=None, ...
# 19  BaggingClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.050559                                          0.096474  (LogisticRegression(C=1.0, class_weight=None, ...
# 57  BaggingClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.047898                                          0.108822  ((ExtraTreeClassifier(class_weight=None, crite...
# 79  BaggingClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.045237                                          0.110488  (LogisticRegression(C=1.0, class_weight=None, ...
# 39  BaggingClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.045237                                          0.103878  (LogisticRegression(C=1.0, class_weight=None, ...
# 26  BaggingClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.042576                                          0.117700  ((ExtraTreeClassifier(class_weight=None, crite...
# 5   BaggingClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.039915                                          0.147547  (ExtraTreeClassifier(class_weight=None, criter...
# 54  BaggingClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.034593                                          0.079116  (LogisticRegression(C=1.0, class_weight=None, ...
# 45  BaggingClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.034593                                          0.135937  (ExtraTreeClassifier(class_weight=None, criter...
# 25  BaggingClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.018627                                          0.140585  (ExtraTreeClassifier(class_weight=None, criter...
# 22  BaggingClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.002661                                          0.163440  (LogisticRegression(C=1.0, class_weight=None, ...
# 23  BaggingClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                           -0.015966                                          0.134966  (ExtraTreeClassifier(class_weight=None, criter...
# 42  BaggingClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.015966                                          0.160756  (LogisticRegression(C=1.0, class_weight=None, ...
# 2   BaggingClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.015966                                          0.160756  (LogisticRegression(C=1.0, class_weight=None, ...
# 24  BaggingClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.018627                                          0.158483  (LogisticRegression(C=1.0, class_weight=None, ...
# 44  BaggingClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.018627                                          0.164621  (LogisticRegression(C=1.0, class_weight=None, ...
# 4   BaggingClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.031932                                          0.157468  (LogisticRegression(C=1.0, class_weight=None, ...
# 3   BaggingClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.031932                                          0.157468  (LogisticRegression(C=1.0, class_weight=None, ...
# 43  BaggingClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.031932                                          0.157468  (LogisticRegression(C=1.0, class_weight=None, ...
# 65  BaggingClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'base_estimator': ExtraTreesClassifier(bootst...                           -0.087813                                          0.209949  ((ExtraTreeClassifier(class_weight=None, crite...
# 1   BaggingClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.143693                                          0.229408  (LogisticRegression(C=1.0, class_weight=None, ...
# 62  BaggingClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.149015                                          0.199038  (LogisticRegression(C=1.0, class_weight=None, ...
# 63  BaggingClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.151676                                          0.208424  (LogisticRegression(C=1.0, class_weight=None, ...
# 21  BaggingClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.156998                                          0.229217  (LogisticRegression(C=1.0, class_weight=None, ...
# 61  BaggingClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.159659                                          0.208667  (LogisticRegression(C=1.0, class_weight=None, ...
# 64  BaggingClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.159659                                          0.205687  (LogisticRegression(C=1.0, class_weight=None, ...
# 41  BaggingClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.159659                                          0.208667  (LogisticRegression(C=1.0, class_weight=None, ...
# 0   BaggingClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 60  BaggingClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 20  BaggingClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 40  BaggingClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                 Model Data Preparation Feature Count Feature Selection Technique                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 70  BaggingClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.114423                                          0.077750  (ExtraTreeClassifier(class_weight=None, criter...
# 51  BaggingClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.106440                                          0.085583  ((ExtraTreeClassifier(class_weight=None, crite...
# 7   BaggingClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.103779                                          0.098962  ((ExtraTreeClassifier(class_weight=None, crite...
# 35  BaggingClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.101118                                          0.090247  ((ExtraTreeClassifier(class_weight=None, crite...
# 29  BaggingClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.101118                                          0.074764  (ExtraTreeClassifier(class_weight=None, criter...
# 11  BaggingClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.101118                                          0.064778  (ExtraTreeClassifier(class_weight=None, criter...
# 49  BaggingClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.101118                                          0.085315  ((ExtraTreeClassifier(class_weight=None, crite...
# 28  BaggingClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.098457                                          0.094317  (ExtraTreeClassifier(class_weight=None, criter...
# 31  BaggingClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.098457                                          0.078702  (ExtraTreeClassifier(class_weight=None, criter...
# 71  BaggingClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.095796                                          0.070299  ((ExtraTreeClassifier(class_weight=None, crite...
# 10  BaggingClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.093135                                          0.078099  (ExtraTreeClassifier(class_weight=None, criter...
# 9   BaggingClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.093135                                          0.104323  ((ExtraTreeClassifier(class_weight=None, crite...
# 52  BaggingClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.093135                                          0.084187  (ExtraTreeClassifier(class_weight=None, criter...
# 48  BaggingClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.090474                                          0.082440  ((ExtraTreeClassifier(class_weight=None, crite...
# 33  BaggingClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.087813                                          0.079756  ((ExtraTreeClassifier(class_weight=None, crite...
# 47  BaggingClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.087813                                          0.070239  ((ExtraTreeClassifier(class_weight=None, crite...
# 55  BaggingClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.087813                                          0.086477  (ExtraTreeClassifier(class_weight=None, criter...
# 72  BaggingClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.087813                                          0.083230  ((ExtraTreeClassifier(class_weight=None, crite...
# 69  BaggingClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.085152                                          0.109996  ((ExtraTreeClassifier(class_weight=None, crite...
# 30  BaggingClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.085152                                          0.102680  ((ExtraTreeClassifier(class_weight=None, crite...
# 50  BaggingClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.082491                                          0.090748  ((ExtraTreeClassifier(class_weight=None, crite...
# 32  BaggingClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.082491                                          0.080084  (ExtraTreeClassifier(class_weight=None, criter...
# 16  BaggingClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.079830                                          0.076013  (ExtraTreeClassifier(class_weight=None, criter...
# 8   BaggingClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.079830                                          0.098771  (ExtraTreeClassifier(class_weight=None, criter...
# 6   BaggingClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.079830                                          0.107653  (ExtraTreeClassifier(class_weight=None, criter...
# 27  BaggingClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.079830                                          0.086517  ((ExtraTreeClassifier(class_weight=None, crite...
# 66  BaggingClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.074508                                          0.091870  (ExtraTreeClassifier(class_weight=None, criter...
# 15  BaggingClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.074508                                          0.081199  (ExtraTreeClassifier(class_weight=None, criter...
# 78  BaggingClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.071847                                          0.089267  (LogisticRegression(C=1.0, class_weight=None, ...
# 13  BaggingClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.071847                                          0.065164  ((ExtraTreeClassifier(class_weight=None, crite...
# 73  BaggingClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.071847                                          0.081556  ((ExtraTreeClassifier(class_weight=None, crite...
# 17  BaggingClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.069186                                          0.096776  ((ExtraTreeClassifier(class_weight=None, crite...
# 14  BaggingClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.069186                                          0.089092  ((ExtraTreeClassifier(class_weight=None, crite...
# 53  BaggingClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.066525                                          0.124346  (ExtraTreeClassifier(class_weight=None, criter...
# 77  BaggingClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.093834  ((ExtraTreeClassifier(class_weight=None, crite...
# 68  BaggingClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.066525                                          0.124227  (ExtraTreeClassifier(class_weight=None, criter...
# 76  BaggingClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.104399  ((ExtraTreeClassifier(class_weight=None, crite...
# 12  BaggingClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.098827  ((ExtraTreeClassifier(class_weight=None, crite...
# 75  BaggingClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.066525                                          0.084990  ((ExtraTreeClassifier(class_weight=None, crite...
# 56  BaggingClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.063864                                          0.076502  (LogisticRegression(C=1.0, class_weight=None, ...
# 46  BaggingClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.063864                                          0.130749  (ExtraTreeClassifier(class_weight=None, criter...
# 34  BaggingClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.063864                                          0.094499  (ExtraTreeClassifier(class_weight=None, criter...
# 36  BaggingClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.063864                                          0.074376  ((ExtraTreeClassifier(class_weight=None, crite...
# 38  BaggingClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.061203                                          0.085797  ((ExtraTreeClassifier(class_weight=None, crite...
# 67  BaggingClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.058542                                          0.056677  (ExtraTreeClassifier(class_weight=None, criter...
# 74  BaggingClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.055881                                          0.065524  (ExtraTreeClassifier(class_weight=None, criter...
# 58  BaggingClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.055881                                          0.081955  ((ExtraTreeClassifier(class_weight=None, crite...
# 37  BaggingClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.053220                                          0.077087  ((ExtraTreeClassifier(class_weight=None, crite...
# 59  BaggingClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.050559                                          0.105520  (LogisticRegression(C=1.0, class_weight=None, ...
# 18  BaggingClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.050559                                          0.111993  (LogisticRegression(C=1.0, class_weight=None, ...
# 19  BaggingClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.050559                                          0.096474  (LogisticRegression(C=1.0, class_weight=None, ...
# 57  BaggingClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.047898                                          0.108822  ((ExtraTreeClassifier(class_weight=None, crite...
# 79  BaggingClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.045237                                          0.110488  (LogisticRegression(C=1.0, class_weight=None, ...
# 39  BaggingClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.045237                                          0.103878  (LogisticRegression(C=1.0, class_weight=None, ...
# 26  BaggingClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': ExtraTreesClassifier(bootst...                            0.042576                                          0.117700  ((ExtraTreeClassifier(class_weight=None, crite...
# 5   BaggingClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.039915                                          0.147547  (ExtraTreeClassifier(class_weight=None, criter...
# 54  BaggingClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.034593                                          0.079116  (LogisticRegression(C=1.0, class_weight=None, ...
# 45  BaggingClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.034593                                          0.135937  (ExtraTreeClassifier(class_weight=None, criter...
# 25  BaggingClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                            0.018627                                          0.140585  (ExtraTreeClassifier(class_weight=None, criter...
# 22  BaggingClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                            0.002661                                          0.163440  (LogisticRegression(C=1.0, class_weight=None, ...
# 23  BaggingClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': ExtraTreeClassifier(class_w...                           -0.015966                                          0.134966  (ExtraTreeClassifier(class_weight=None, criter...
# 42  BaggingClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.015966                                          0.160756  (LogisticRegression(C=1.0, class_weight=None, ...
# 2   BaggingClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.015966                                          0.160756  (LogisticRegression(C=1.0, class_weight=None, ...
# 24  BaggingClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.018627                                          0.158483  (LogisticRegression(C=1.0, class_weight=None, ...
# 44  BaggingClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.018627                                          0.164621  (LogisticRegression(C=1.0, class_weight=None, ...
# 4   BaggingClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.031932                                          0.157468  (LogisticRegression(C=1.0, class_weight=None, ...
# 3   BaggingClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.031932                                          0.157468  (LogisticRegression(C=1.0, class_weight=None, ...
# 43  BaggingClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.031932                                          0.157468  (LogisticRegression(C=1.0, class_weight=None, ...
# 65  BaggingClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'base_estimator': ExtraTreesClassifier(bootst...                           -0.087813                                          0.209949  ((ExtraTreeClassifier(class_weight=None, crite...
# 1   BaggingClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.143693                                          0.229408  (LogisticRegression(C=1.0, class_weight=None, ...
# 62  BaggingClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.149015                                          0.199038  (LogisticRegression(C=1.0, class_weight=None, ...
# 63  BaggingClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.151676                                          0.208424  (LogisticRegression(C=1.0, class_weight=None, ...
# 21  BaggingClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.156998                                          0.229217  (LogisticRegression(C=1.0, class_weight=None, ...
# 61  BaggingClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.159659                                          0.208667  (LogisticRegression(C=1.0, class_weight=None, ...
# 64  BaggingClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.159659                                          0.205687  (LogisticRegression(C=1.0, class_weight=None, ...
# 41  BaggingClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'base_estimator': LogisticRegression(C=1.0, c...                           -0.159659                                          0.208667  (LogisticRegression(C=1.0, class_weight=None, ...
# 0   BaggingClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 60  BaggingClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 20  BaggingClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 40  BaggingClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'base_estimator': DecisionTreeClassifier(clas...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...

# %%
#result_table.to_pickle("result_table_BaggingClassifier.pkl")
result_table = pd.read_pickle("result_table_BaggingClassifier.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# BaggingClassifier(base_estimator=ExtraTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, random_state=None,
#           splitter='random'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=200, n_jobs=None, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'valuePerSecond' 'lineItemVoidsPerPosition'
#  'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'secondsPerEuro']
# {'base_estimator': ExtraTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, random_state=None,
#           splitter='random'), 'n_estimators': 200}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  0
# True positive:  104
# 520 for 1879 instances in the test set
# 0.2767429483767962 per instance in the test set
