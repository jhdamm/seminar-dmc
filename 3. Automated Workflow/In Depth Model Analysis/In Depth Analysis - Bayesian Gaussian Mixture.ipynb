# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.mixture import BayesianGaussianMixture

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(BayesianGaussianMixture(),
                 dict(n_components = range(1,3),
                      covariance_type = ['full', 'tied', 'diag', 'spherical'], 
                      max_iter = range(50,200,50),
                      n_init = range(1,3),
                      init_params = ['kmeans', 'random']),
                 cv = skf,
                 scoring = my_custom_score),    
]           
                 
                 
iterations = 10                
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(BayesianGaussianMixture(),
                 dict(),
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished BayesianGaussianMixture with No Scaling and 1 features after 15.27 seconds
# Finished BayesianGaussianMixture with No Scaling and 2 features after 37.17 seconds
# Finished BayesianGaussianMixture with No Scaling and 3 features after 42.07 seconds
# Finished BayesianGaussianMixture with No Scaling and 4 features after 23.35 seconds
# Finished BayesianGaussianMixture with No Scaling and 5 features after 22.03 seconds
# Finished BayesianGaussianMixture with No Scaling and 6 features after 21.37 seconds
# Finished BayesianGaussianMixture with No Scaling and 7 features after 21.96 seconds
# Finished BayesianGaussianMixture with No Scaling and 8 features after 26.83 seconds
# Finished BayesianGaussianMixture with No Scaling and 9 features after 25.23 seconds
# Finished BayesianGaussianMixture with No Scaling and 10 features after 28.98 seconds
# Finished BayesianGaussianMixture with No Scaling and 11 features after 29.13 seconds
# Finished BayesianGaussianMixture with No Scaling and 12 features after 34.69 seconds
# Finished BayesianGaussianMixture with No Scaling and 13 features after 40.76 seconds
# Finished BayesianGaussianMixture with No Scaling and 14 features after 45.07 seconds
# Finished BayesianGaussianMixture with No Scaling and 15 features after 40.25 seconds
# Finished BayesianGaussianMixture with No Scaling and 16 features after 37.0 seconds
# Finished BayesianGaussianMixture with No Scaling and 17 features after 33.73 seconds
# Finished BayesianGaussianMixture with No Scaling and 18 features after 32.17 seconds
# Finished BayesianGaussianMixture with No Scaling and 19 features after 32.16 seconds
# Finished BayesianGaussianMixture with No Scaling and 20 features after 31.77 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 1 features after 15.02 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 2 features after 37.95 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 3 features after 40.49 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 4 features after 21.46 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 5 features after 21.01 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 6 features after 21.95 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 7 features after 23.34 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 8 features after 26.01 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 9 features after 25.46 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 10 features after 27.64 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 11 features after 25.87 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 12 features after 32.91 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 13 features after 34.78 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 14 features after 36.45 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 15 features after 36.41 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 16 features after 33.69 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 17 features after 28.76 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 18 features after 28.88 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 19 features after 29.76 seconds
# Finished BayesianGaussianMixture with MinMaxScaler and 20 features after 29.12 seconds
# Finished BayesianGaussianMixture with StandardScaler and 1 features after 13.47 seconds
# Finished BayesianGaussianMixture with StandardScaler and 2 features after 33.25 seconds
# Finished BayesianGaussianMixture with StandardScaler and 3 features after 37.87 seconds
# Finished BayesianGaussianMixture with StandardScaler and 4 features after 19.33 seconds
# Finished BayesianGaussianMixture with StandardScaler and 5 features after 20.51 seconds
# Finished BayesianGaussianMixture with StandardScaler and 6 features after 22.34 seconds
# Finished BayesianGaussianMixture with StandardScaler and 7 features after 22.91 seconds
# Finished BayesianGaussianMixture with StandardScaler and 8 features after 26.9 seconds
# Finished BayesianGaussianMixture with StandardScaler and 9 features after 25.71 seconds
# Finished BayesianGaussianMixture with StandardScaler and 10 features after 27.64 seconds
# Finished BayesianGaussianMixture with StandardScaler and 11 features after 25.48 seconds
# Finished BayesianGaussianMixture with StandardScaler and 12 features after 30.94 seconds
# Finished BayesianGaussianMixture with StandardScaler and 13 features after 35.95 seconds
# Finished BayesianGaussianMixture with StandardScaler and 14 features after 38.61 seconds
# Finished BayesianGaussianMixture with StandardScaler and 15 features after 38.82 seconds
# Finished BayesianGaussianMixture with StandardScaler and 16 features after 36.33 seconds
# Finished BayesianGaussianMixture with StandardScaler and 17 features after 31.57 seconds
# Finished BayesianGaussianMixture with StandardScaler and 18 features after 32.5 seconds
# Finished BayesianGaussianMixture with StandardScaler and 19 features after 31.87 seconds
# Finished BayesianGaussianMixture with StandardScaler and 20 features after 33.14 seconds
# Finished BayesianGaussianMixture with LogScaler and 1 features after 15.29 seconds
# Finished BayesianGaussianMixture with LogScaler and 2 features after 36.51 seconds
# Finished BayesianGaussianMixture with LogScaler and 3 features after 19.68 seconds
# Finished BayesianGaussianMixture with LogScaler and 4 features after 22.1 seconds
# Finished BayesianGaussianMixture with LogScaler and 5 features after 28.98 seconds
# Finished BayesianGaussianMixture with LogScaler and 6 features after 30.39 seconds
# Finished BayesianGaussianMixture with LogScaler and 7 features after 22.67 seconds
# Finished BayesianGaussianMixture with LogScaler and 8 features after 22.51 seconds
# Finished BayesianGaussianMixture with LogScaler and 9 features after 23.21 seconds
# Finished BayesianGaussianMixture with LogScaler and 10 features after 23.17 seconds
# Finished BayesianGaussianMixture with LogScaler and 11 features after 24.82 seconds
# Finished BayesianGaussianMixture with LogScaler and 12 features after 23.5 seconds
# Finished BayesianGaussianMixture with LogScaler and 13 features after 20.81 seconds
# Finished BayesianGaussianMixture with LogScaler and 14 features after 22.19 seconds
# Finished BayesianGaussianMixture with LogScaler and 15 features after 23.55 seconds
# Finished BayesianGaussianMixture with LogScaler and 16 features after 25.11 seconds
# Finished BayesianGaussianMixture with LogScaler and 17 features after 26.26 seconds
# Finished BayesianGaussianMixture with LogScaler and 18 features after 25.56 seconds
# Finished BayesianGaussianMixture with LogScaler and 19 features after 27.38 seconds
# Finished BayesianGaussianMixture with LogScaler and 20 features after 27.74 seconds
#                       Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 0   BayesianGaussianMixture       No Scaling             1                                       [trustLevel]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 1   BayesianGaussianMixture       No Scaling             2                     [trustLevel, scannedLineItems]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 58  BayesianGaussianMixture   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 57  BayesianGaussianMixture   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 56  BayesianGaussianMixture   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 55  BayesianGaussianMixture   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 54  BayesianGaussianMixture   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 53  BayesianGaussianMixture   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 52  BayesianGaussianMixture   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 51  BayesianGaussianMixture   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 50  BayesianGaussianMixture   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 49  BayesianGaussianMixture   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 48  BayesianGaussianMixture   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 47  BayesianGaussianMixture   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 46  BayesianGaussianMixture   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 45  BayesianGaussianMixture   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 44  BayesianGaussianMixture   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 43  BayesianGaussianMixture   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 42  BayesianGaussianMixture   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 59  BayesianGaussianMixture   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 60  BayesianGaussianMixture        LogScaler             1                                       [trustLevel]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 61  BayesianGaussianMixture        LogScaler             2                     [trustLevel, scannedLineItems]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 71  BayesianGaussianMixture        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 78  BayesianGaussianMixture        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 77  BayesianGaussianMixture        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 76  BayesianGaussianMixture        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 75  BayesianGaussianMixture        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 74  BayesianGaussianMixture        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 73  BayesianGaussianMixture        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 72  BayesianGaussianMixture        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 70  BayesianGaussianMixture        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 62  BayesianGaussianMixture        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 69  BayesianGaussianMixture        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 68  BayesianGaussianMixture        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 67  BayesianGaussianMixture        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 66  BayesianGaussianMixture        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 65  BayesianGaussianMixture        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 64  BayesianGaussianMixture        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 63  BayesianGaussianMixture        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 41  BayesianGaussianMixture   StandardScaler             2                     [trustLevel, scannedLineItems]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 40  BayesianGaussianMixture   StandardScaler             1                                       [trustLevel]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 39  BayesianGaussianMixture     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 10  BayesianGaussianMixture       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 17  BayesianGaussianMixture       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 16  BayesianGaussianMixture       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 15  BayesianGaussianMixture       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 14  BayesianGaussianMixture       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 13  BayesianGaussianMixture       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 12  BayesianGaussianMixture       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 11  BayesianGaussianMixture       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 9   BayesianGaussianMixture       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 19  BayesianGaussianMixture       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 8   BayesianGaussianMixture       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 7   BayesianGaussianMixture       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 6   BayesianGaussianMixture       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 5   BayesianGaussianMixture       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 4   BayesianGaussianMixture       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 3   BayesianGaussianMixture       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 2   BayesianGaussianMixture       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 18  BayesianGaussianMixture       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 20  BayesianGaussianMixture     MinMaxScaler             1                                       [trustLevel]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 38  BayesianGaussianMixture     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 30  BayesianGaussianMixture     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 37  BayesianGaussianMixture     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 36  BayesianGaussianMixture     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 35  BayesianGaussianMixture     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 34  BayesianGaussianMixture     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 33  BayesianGaussianMixture     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 32  BayesianGaussianMixture     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 31  BayesianGaussianMixture     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 29  BayesianGaussianMixture     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 21  BayesianGaussianMixture     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 28  BayesianGaussianMixture     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 27  BayesianGaussianMixture     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 26  BayesianGaussianMixture     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 25  BayesianGaussianMixture     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 24  BayesianGaussianMixture     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 23  BayesianGaussianMixture     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 22  BayesianGaussianMixture     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest
# 79  BayesianGaussianMixture        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'covariance_type': 'full', 'init_params': 'km...                           -0.276743                                          0.011709  BayesianGaussianMixture(covariance_prior=None,...                 SelectKBest

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)

# %%
#result_table.to_pickle("result_table_BayesianGaussianMixture.pkl")
result_table = pd.read_pickle("result_table_BayesianGaussianMixture.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# BayesianGaussianMixture(covariance_prior=None, covariance_type='full',
#             degrees_of_freedom_prior=None, init_params='kmeans',
#             max_iter=50, mean_precision_prior=None, mean_prior=None,
#             n_components=1, n_init=1, random_state=None, reg_covar=1e-06,
#             tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#             weight_concentration_prior=None,
#             weight_concentration_prior_type='dirichlet_process')
# ['trustLevel']
# {'covariance_type': 'full', 'init_params': 'kmeans', 'max_iter': 50, 'n_components': 1, 'n_init': 1}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  104
# True positive:  0
# -520 for 1879 instances in the test set
# -0.2767429483767962 per instance in the test set
