# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.linear_model import Perceptron

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(Perceptron(),
                 dict(penalty = ['l2', 'l1', 'elasticnet', None],
                      alpha = np.arange(0.0005, 0.001, 0.0005),
                      fit_intercept = [True, False],
                      max_iter = range(5,100,5)),
                 cv = skf,
                 scoring = my_custom_score),    
]           
                 
                 
iterations = 10                
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(Perceptron(),
                 dict(penalty = ['l2', 'l1', 'elasticnet']),
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished Perceptron with No Scaling and 1 features after 26.55 seconds
# Finished Perceptron with No Scaling and 2 features after 27.8 seconds
# Finished Perceptron with No Scaling and 3 features after 28.51 seconds
# Finished Perceptron with No Scaling and 4 features after 29.95 seconds
# Finished Perceptron with No Scaling and 5 features after 31.59 seconds
# Finished Perceptron with No Scaling and 6 features after 31.62 seconds
# Finished Perceptron with No Scaling and 7 features after 33.22 seconds
# Finished Perceptron with No Scaling and 8 features after 33.87 seconds
# Finished Perceptron with No Scaling and 9 features after 35.21 seconds
# Finished Perceptron with No Scaling and 10 features after 36.03 seconds
# Finished Perceptron with No Scaling and 11 features after 36.83 seconds
# Finished Perceptron with No Scaling and 12 features after 36.74 seconds
# Finished Perceptron with No Scaling and 13 features after 38.27 seconds
# Finished Perceptron with No Scaling and 14 features after 37.82 seconds
# Finished Perceptron with No Scaling and 15 features after 44.6 seconds
# Finished Perceptron with No Scaling and 16 features after 45.08 seconds
# Finished Perceptron with No Scaling and 17 features after 46.24 seconds
# Finished Perceptron with No Scaling and 18 features after 48.11 seconds
# Finished Perceptron with No Scaling and 19 features after 47.55 seconds
# Finished Perceptron with No Scaling and 20 features after 48.18 seconds
# Finished Perceptron with MinMaxScaler and 1 features after 24.44 seconds
# Finished Perceptron with MinMaxScaler and 2 features after 26.25 seconds
# Finished Perceptron with MinMaxScaler and 3 features after 27.27 seconds
# Finished Perceptron with MinMaxScaler and 4 features after 27.8 seconds
# Finished Perceptron with MinMaxScaler and 5 features after 30.15 seconds
# Finished Perceptron with MinMaxScaler and 6 features after 30.13 seconds
# Finished Perceptron with MinMaxScaler and 7 features after 32.49 seconds
# Finished Perceptron with MinMaxScaler and 8 features after 33.02 seconds
# Finished Perceptron with MinMaxScaler and 9 features after 33.91 seconds
# Finished Perceptron with MinMaxScaler and 10 features after 34.19 seconds
# Finished Perceptron with MinMaxScaler and 11 features after 35.62 seconds
# Finished Perceptron with MinMaxScaler and 12 features after 35.84 seconds
# Finished Perceptron with MinMaxScaler and 13 features after 36.47 seconds
# Finished Perceptron with MinMaxScaler and 14 features after 37.91 seconds
# Finished Perceptron with MinMaxScaler and 15 features after 41.46 seconds
# Finished Perceptron with MinMaxScaler and 16 features after 36.24 seconds
# Finished Perceptron with MinMaxScaler and 17 features after 35.47 seconds
# Finished Perceptron with MinMaxScaler and 18 features after 36.16 seconds
# Finished Perceptron with MinMaxScaler and 19 features after 36.71 seconds
# Finished Perceptron with MinMaxScaler and 20 features after 37.31 seconds
# Finished Perceptron with StandardScaler and 1 features after 15.5 seconds
# Finished Perceptron with StandardScaler and 2 features after 16.46 seconds
# Finished Perceptron with StandardScaler and 3 features after 17.35 seconds
# Finished Perceptron with StandardScaler and 4 features after 17.9 seconds
# Finished Perceptron with StandardScaler and 5 features after 18.71 seconds
# Finished Perceptron with StandardScaler and 6 features after 18.99 seconds
# Finished Perceptron with StandardScaler and 7 features after 19.83 seconds
# Finished Perceptron with StandardScaler and 8 features after 20.32 seconds
# Finished Perceptron with StandardScaler and 9 features after 21.37 seconds
# Finished Perceptron with StandardScaler and 10 features after 21.44 seconds
# Finished Perceptron with StandardScaler and 11 features after 21.92 seconds
# Finished Perceptron with StandardScaler and 12 features after 22.34 seconds
# Finished Perceptron with StandardScaler and 13 features after 23.13 seconds
# Finished Perceptron with StandardScaler and 14 features after 23.71 seconds
# Finished Perceptron with StandardScaler and 15 features after 33.45 seconds
# Finished Perceptron with StandardScaler and 16 features after 34.73 seconds
# Finished Perceptron with StandardScaler and 17 features after 35.41 seconds
# Finished Perceptron with StandardScaler and 18 features after 36.41 seconds
# Finished Perceptron with StandardScaler and 19 features after 38.23 seconds
# Finished Perceptron with StandardScaler and 20 features after 36.53 seconds
# Finished Perceptron with LogScaler and 1 features after 15.4 seconds
# Finished Perceptron with LogScaler and 2 features after 16.58 seconds
# Finished Perceptron with LogScaler and 3 features after 17.06 seconds
# Finished Perceptron with LogScaler and 4 features after 17.75 seconds
# Finished Perceptron with LogScaler and 5 features after 18.67 seconds
# Finished Perceptron with LogScaler and 6 features after 19.12 seconds
# Finished Perceptron with LogScaler and 7 features after 19.83 seconds
# Finished Perceptron with LogScaler and 8 features after 20.14 seconds
# Finished Perceptron with LogScaler and 9 features after 21.29 seconds
# Finished Perceptron with LogScaler and 10 features after 21.6 seconds
# Finished Perceptron with LogScaler and 11 features after 22.04 seconds
# Finished Perceptron with LogScaler and 12 features after 22.55 seconds
# Finished Perceptron with LogScaler and 13 features after 23.25 seconds
# Finished Perceptron with LogScaler and 14 features after 23.5 seconds
# Finished Perceptron with LogScaler and 15 features after 33.08 seconds
# Finished Perceptron with LogScaler and 16 features after 33.02 seconds
# Finished Perceptron with LogScaler and 17 features after 35.06 seconds
# Finished Perceptron with LogScaler and 18 features after 36.09 seconds
# Finished Perceptron with LogScaler and 19 features after 36.22 seconds
# Finished Perceptron with LogScaler and 20 features after 36.72 seconds
#           Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 131  Perceptron        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.167642                                          0.189601  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 127  Perceptron        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.186269                                          0.201408  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 129  Perceptron        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.212879                                          0.103857  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 133  Perceptron        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.218201                                          0.215489  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 84   Perceptron   StandardScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 2    Perceptron       No Scaling             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 43   Perceptron     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 125  Perceptron        LogScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 97   Perceptron   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 99   Perceptron   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 93   Perceptron   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 101  Perceptron   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 103  Perceptron   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 105  Perceptron   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 107  Perceptron   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 109  Perceptron   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 95   Perceptron   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 0    Perceptron       No Scaling             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 113  Perceptron   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 83   Perceptron   StandardScaler             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 1    Perceptron       No Scaling             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 81   Perceptron     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 80   Perceptron     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 79   Perceptron     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 78   Perceptron     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 77   Perceptron     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 76   Perceptron     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 74   Perceptron     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 72   Perceptron     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 70   Perceptron     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 68   Perceptron     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 66   Perceptron     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 111  Perceptron   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 119  Perceptron   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 115  Perceptron   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 144  Perceptron        LogScaler            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 162  Perceptron        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 161  Perceptron        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 160  Perceptron        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 159  Perceptron        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 158  Perceptron        LogScaler            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 156  Perceptron        LogScaler            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 154  Perceptron        LogScaler            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 152  Perceptron        LogScaler            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 150  Perceptron        LogScaler            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 148  Perceptron        LogScaler            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 146  Perceptron        LogScaler            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 142  Perceptron        LogScaler            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 117  Perceptron   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 140  Perceptron        LogScaler             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 138  Perceptron        LogScaler             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 136  Perceptron        LogScaler             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 134  Perceptron        LogScaler             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 124  Perceptron        LogScaler             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 123  Perceptron        LogScaler             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 122  Perceptron   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 121  Perceptron   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 120  Perceptron   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 62   Perceptron     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 118  Perceptron   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 64   Perceptron     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 82   Perceptron   StandardScaler             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 163  Perceptron        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 15   Perceptron       No Scaling             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 19   Perceptron       No Scaling            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 21   Perceptron       No Scaling            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 23   Perceptron       No Scaling            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 25   Perceptron       No Scaling            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 27   Perceptron       No Scaling            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 29   Perceptron       No Scaling            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 42   Perceptron     MinMaxScaler             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 41   Perceptron     MinMaxScaler             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 31   Perceptron       No Scaling            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 40   Perceptron       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 33   Perceptron       No Scaling            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 39   Perceptron       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 38   Perceptron       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 37   Perceptron       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 36   Perceptron       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 17   Perceptron       No Scaling             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 35   Perceptron       No Scaling            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 54   Perceptron     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 11   Perceptron       No Scaling             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 56   Perceptron     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 60   Perceptron     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 52   Perceptron     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 58   Perceptron     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 13   Perceptron       No Scaling             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 141  Perceptron        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.303353                                          0.055660  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 143  Perceptron        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.303353                                          0.049882  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 145  Perceptron        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.303353                                          0.049882  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 106  Perceptron   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 153  Perceptron        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 67   Perceptron     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 65   Perceptron     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 69   Perceptron     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 108  Perceptron   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 110  Perceptron   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 151  Perceptron        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 149  Perceptron        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 28   Perceptron       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 147  Perceptron        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 26   Perceptron       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 24   Perceptron       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 30   Perceptron       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.087123  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 63   Perceptron     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 22   Perceptron       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 112  Perceptron   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.087123  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 18   Perceptron       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 14   Perceptron       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 16   Perceptron       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 20   Perceptron       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 61   Perceptron     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 104  Perceptron   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 57   Perceptron     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 102  Perceptron   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 100  Perceptron   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 98   Perceptron   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 96   Perceptron   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 55   Perceptron     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 59   Perceptron     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 71   Perceptron     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.087123  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 137  Perceptron        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.067319  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 47   Perceptron     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 49   Perceptron     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 88   Perceptron   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 73   Perceptron     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.089731  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 114  Perceptron   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.089731  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 90   Perceptron   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 8    Perceptron       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 6    Perceptron       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 32   Perceptron       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.089731  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 139  Perceptron        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.084035  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 155  Perceptron        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 157  Perceptron        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 75   Perceptron     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 51   Perceptron     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.080324  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 4    Perceptron       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.116680  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 10   Perceptron       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.080324  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 34   Perceptron       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 92   Perceptron   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.080324  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 86   Perceptron   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.116680  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 116  Perceptron   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 45   Perceptron     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.116680  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 135  Perceptron        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 53   Perceptron     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 12   Perceptron       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 94   Perceptron   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 85   Perceptron   StandardScaler             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 3    Perceptron       No Scaling             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 44   Perceptron     MinMaxScaler             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 126  Perceptron        LogScaler             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 48   Perceptron     MinMaxScaler             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 89   Perceptron   StandardScaler             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 130  Perceptron        LogScaler             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 7    Perceptron       No Scaling             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 91   Perceptron   StandardScaler             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 9    Perceptron       No Scaling             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 132  Perceptron        LogScaler             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 50   Perceptron     MinMaxScaler             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 128  Perceptron        LogScaler             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 5    Perceptron       No Scaling             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 87   Perceptron   StandardScaler             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 46   Perceptron     MinMaxScaler             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#           Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 131  Perceptron        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.167642                                          0.189601  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 127  Perceptron        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.186269                                          0.201408  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 129  Perceptron        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.212879                                          0.103857  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 133  Perceptron        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.218201                                          0.215489  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 84   Perceptron   StandardScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 2    Perceptron       No Scaling             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 43   Perceptron     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 125  Perceptron        LogScaler             2                     [trustLevel, scannedLineItems]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.236828                                          0.106678  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 97   Perceptron   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 99   Perceptron   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 93   Perceptron   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 101  Perceptron   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 103  Perceptron   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 105  Perceptron   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 107  Perceptron   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 109  Perceptron   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 95   Perceptron   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 0    Perceptron       No Scaling             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 113  Perceptron   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 83   Perceptron   StandardScaler             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 1    Perceptron       No Scaling             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 81   Perceptron     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 80   Perceptron     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 79   Perceptron     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 78   Perceptron     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 77   Perceptron     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 76   Perceptron     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 74   Perceptron     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 72   Perceptron     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 70   Perceptron     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 68   Perceptron     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 66   Perceptron     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 111  Perceptron   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 119  Perceptron   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 115  Perceptron   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 144  Perceptron        LogScaler            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 162  Perceptron        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 161  Perceptron        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 160  Perceptron        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 159  Perceptron        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 158  Perceptron        LogScaler            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 156  Perceptron        LogScaler            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 154  Perceptron        LogScaler            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 152  Perceptron        LogScaler            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 150  Perceptron        LogScaler            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 148  Perceptron        LogScaler            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 146  Perceptron        LogScaler            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 142  Perceptron        LogScaler            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 117  Perceptron   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 140  Perceptron        LogScaler             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 138  Perceptron        LogScaler             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 136  Perceptron        LogScaler             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 134  Perceptron        LogScaler             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 124  Perceptron        LogScaler             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 123  Perceptron        LogScaler             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 122  Perceptron   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 121  Perceptron   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 120  Perceptron   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 62   Perceptron     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 118  Perceptron   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 64   Perceptron     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 82   Perceptron   StandardScaler             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 163  Perceptron        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 15   Perceptron       No Scaling             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 19   Perceptron       No Scaling            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 21   Perceptron       No Scaling            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 23   Perceptron       No Scaling            12  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 25   Perceptron       No Scaling            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 27   Perceptron       No Scaling            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 29   Perceptron       No Scaling            15  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 42   Perceptron     MinMaxScaler             1                                   [secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 41   Perceptron     MinMaxScaler             1                                       [trustLevel]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 31   Perceptron       No Scaling            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 40   Perceptron       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                       RFECV
# 33   Perceptron       No Scaling            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 39   Perceptron       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 38   Perceptron       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 37   Perceptron       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 36   Perceptron       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 17   Perceptron       No Scaling             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 35   Perceptron       No Scaling            18  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 54   Perceptron     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 11   Perceptron       No Scaling             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 56   Perceptron     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 60   Perceptron     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 52   Perceptron     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 58   Perceptron     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 13   Perceptron       No Scaling             7  [trustLevel, totalScanTimeInSeconds, grandTota...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.276743                                          0.011709  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 141  Perceptron        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.303353                                          0.055660  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 143  Perceptron        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.303353                                          0.049882  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 145  Perceptron        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.303353                                          0.049882  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 106  Perceptron   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 153  Perceptron        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 67   Perceptron     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 65   Perceptron     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 69   Perceptron     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 108  Perceptron   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 110  Perceptron   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 151  Perceptron        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 149  Perceptron        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 28   Perceptron       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 147  Perceptron        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055970  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 26   Perceptron       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 24   Perceptron       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.316658                                          0.055546  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 30   Perceptron       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.087123  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 63   Perceptron     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 22   Perceptron       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 112  Perceptron   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.087123  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 18   Perceptron       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 14   Perceptron       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 16   Perceptron       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 20   Perceptron       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 61   Perceptron     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 104  Perceptron   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 57   Perceptron     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 102  Perceptron   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 100  Perceptron   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 98   Perceptron   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 96   Perceptron   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 55   Perceptron     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058507  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 59   Perceptron     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.058101  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 71   Perceptron     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.329963                                          0.087123  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 137  Perceptron        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.067319  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 47   Perceptron     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 49   Perceptron     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 88   Perceptron   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 73   Perceptron     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.089731  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 114  Perceptron   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.089731  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 90   Perceptron   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 8    Perceptron       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 6    Perceptron       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.343268                                          0.057551  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 32   Perceptron       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.343268                                          0.089731  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 139  Perceptron        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.084035  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 155  Perceptron        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 157  Perceptron        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 75   Perceptron     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 51   Perceptron     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.080324  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 4    Perceptron       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.116680  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 10   Perceptron       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.080324  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 34   Perceptron       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 92   Perceptron   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.080324  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 86   Perceptron   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.116680  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 116  Perceptron   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.091056  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 45   Perceptron     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.356573                                          0.116680  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 135  Perceptron        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 53   Perceptron     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 12   Perceptron       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 94   Perceptron   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.369878                                          0.113116  Perceptron(alpha=0.0005, class_weight=None, ea...                 SelectKBest
# 85   Perceptron   StandardScaler             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 3    Perceptron       No Scaling             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 44   Perceptron     MinMaxScaler             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 126  Perceptron        LogScaler             2                 [scannedLineItems, secondsPerEuro]  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.489622                                          0.396779  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 48   Perceptron     MinMaxScaler             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 89   Perceptron   StandardScaler             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 130  Perceptron        LogScaler             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 7    Perceptron       No Scaling             4  [grandTotal, scannedLineItems, pricePerScanned...  {'alpha': 0.0005, 'fit_intercept': False, 'max...                           -0.497605                                          0.379382  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 91   Perceptron   StandardScaler             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 9    Perceptron       No Scaling             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 132  Perceptron        LogScaler             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 50   Perceptron     MinMaxScaler             5  [trustLevel, grandTotal, scannedLineItems, pri...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.502927                                          0.321477  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 128  Perceptron        LogScaler             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 5    Perceptron       No Scaling             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 87   Perceptron   StandardScaler             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE
# 46   Perceptron     MinMaxScaler             3  [scannedLineItems, pricePerScannedLineItem, se...  {'alpha': 0.0005, 'fit_intercept': True, 'max_...                           -0.582757                                          0.441433  Perceptron(alpha=0.0005, class_weight=None, ea...                         RFE

# %%
#result_table.to_pickle("result_table_Perceptron.pkl")
result_table = pd.read_pickle("result_table_Perceptron.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# Perceptron(alpha=0.0005, class_weight=None, early_stopping=False, eta0=1.0,
#       fit_intercept=True, max_iter=55, n_iter=None, n_iter_no_change=5,
#       n_jobs=None, penalty='l1', random_state=0, shuffle=True, tol=None,
#       validation_fraction=0.1, verbose=0, warm_start=False)
# ['trustLevel' 'lineItemVoidsPerPosition' 'scannedLineItems'
#  'pricePerScannedLineItem' 'quantityModificationsPerScannedLineItem']
# {'alpha': 0.0005, 'fit_intercept': True, 'max_iter': 55, 'penalty': 'l1'}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1738
# False positive:  37
# False negative:  19
# True positive:  85
# -595 for 1879 instances in the test set
# -0.31665779670037253 per instance in the test set
