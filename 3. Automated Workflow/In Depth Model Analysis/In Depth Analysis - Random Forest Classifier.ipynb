# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(RandomForestClassifier(),
                 dict(n_estimators = range(5,200,5),
                      criterion = ['entropy', 'gini']),
                 cv = skf,
                 scoring = my_custom_score)
]           
                 
                 
iterations = 10                
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(RandomForestClassifier(),
                 dict(n_estimators = range(5,200,5),
                      criterion = ['entropy', 'gini']),
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,2):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")


        
        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished RandomForestClassifier with No Scaling and 1 features after 161.16 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 2 features after 179.12 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 3 features after 220.02 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 4 features after 261.35 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 5 features after 262.04 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 6 features after 264.38 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 7 features after 258.1 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 8 features after 253.45 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 9 features after 286.05 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 10 features after 297.61 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 11 features after 314.87 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 12 features after 324.43 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 13 features after 310.78 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 14 features after 272.13 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 15 features after 215.26 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 16 features after 300.45 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 17 features after 250.83 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 18 features after 302.91 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 19 features after 251.77 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished RandomForestClassifier with No Scaling and 20 features after 250.46 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
#                      Model Data Preparation Feature Count                                           Features                             Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 17  RandomForestClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 40}                            0.117084                                          0.080705  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 18  RandomForestClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 55}                            0.109101                                          0.105028  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 16  RandomForestClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...      {'criterion': 'gini', 'n_estimators': 20}                            0.095796                                          0.092946  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 20  RandomForestClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 170}                            0.085152                                          0.074804  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 30  RandomForestClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 15}                            0.085152                                          0.102044  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 22  RandomForestClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 120}                            0.085152                                          0.082061  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 15  RandomForestClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...   {'criterion': 'entropy', 'n_estimators': 25}                            0.085152                                          0.118621  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 11  RandomForestClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 10}                            0.085152                                          0.127551  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 24  RandomForestClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 180}                            0.085152                                          0.080383  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 25  RandomForestClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 50}                            0.079830                                          0.076840  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 14  RandomForestClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...   {'criterion': 'entropy', 'n_estimators': 70}                            0.077169                                          0.116035  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 12  RandomForestClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 90}                            0.074508                                          0.059202  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 13  RandomForestClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 40}                            0.071847                                          0.097310  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 19  RandomForestClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, grandTota...      {'criterion': 'gini', 'n_estimators': 85}                            0.071847                                          0.088066  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 32  RandomForestClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 95}                            0.066525                                          0.092217  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 33  RandomForestClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 150}                            0.066525                                          0.106367  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 28  RandomForestClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...      {'criterion': 'gini', 'n_estimators': 65}                            0.063864                                          0.096566  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 26  RandomForestClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 130}                            0.063864                                          0.099530  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 38  RandomForestClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 45}                            0.063864                                          0.095302  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 31  RandomForestClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 70}                            0.061203                                          0.112165  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 21  RandomForestClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 30}                            0.061203                                          0.109626  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 23  RandomForestClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 75}                            0.061203                                          0.101539  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 37  RandomForestClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 15}                            0.058542                                          0.091280  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 27  RandomForestClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 20}                            0.055881                                          0.109312  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 36  RandomForestClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 30}                            0.055881                                          0.096886  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 40  RandomForestClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...      {'criterion': 'gini', 'n_estimators': 15}                            0.055881                                          0.103924  (DecisionTreeClassifier(class_weight=None, cri...                       RFECV
# 29  RandomForestClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 80}                            0.053220                                          0.109698  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 35  RandomForestClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 35}                            0.053220                                          0.095709  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 39  RandomForestClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 120}                            0.053220                                          0.104336  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 9   RandomForestClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 105}                            0.045237                                          0.160779  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 34  RandomForestClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 85}                            0.045237                                          0.125241  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 10  RandomForestClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 100}                            0.039915                                          0.132945  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 6   RandomForestClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 10}                           -0.055881                                          0.178286  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 5   RandomForestClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...       {'criterion': 'gini', 'n_estimators': 5}                           -0.063864                                          0.174134  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 4   RandomForestClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 15}                           -0.069186                                          0.146054  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 8   RandomForestClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 115}                           -0.077169                                          0.149066  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 7   RandomForestClassifier       No Scaling             4  [trustLevel, scannedLineItemsPerSecond, scanne...      {'criterion': 'gini', 'n_estimators': 30}                           -0.079830                                          0.159938  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 3   RandomForestClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 20}                           -0.159659                                          0.208667  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 2   RandomForestClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 30}                           -0.159659                                          0.208667  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 1   RandomForestClassifier       No Scaling             1                                 [scannedLineItems]    {'criterion': 'entropy', 'n_estimators': 5}                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 0   RandomForestClassifier       No Scaling             1                                       [trustLevel]    {'criterion': 'entropy', 'n_estimators': 5}                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                      Model Data Preparation Feature Count                                           Features                             Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 17  RandomForestClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 40}                            0.117084                                          0.080705  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 18  RandomForestClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 55}                            0.109101                                          0.105028  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 16  RandomForestClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...      {'criterion': 'gini', 'n_estimators': 20}                            0.095796                                          0.092946  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 20  RandomForestClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 170}                            0.085152                                          0.074804  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 30  RandomForestClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 15}                            0.085152                                          0.102044  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 22  RandomForestClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 120}                            0.085152                                          0.082061  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 15  RandomForestClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...   {'criterion': 'entropy', 'n_estimators': 25}                            0.085152                                          0.118621  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 11  RandomForestClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 10}                            0.085152                                          0.127551  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 24  RandomForestClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 180}                            0.085152                                          0.080383  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 25  RandomForestClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 50}                            0.079830                                          0.076840  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 14  RandomForestClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...   {'criterion': 'entropy', 'n_estimators': 70}                            0.077169                                          0.116035  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 12  RandomForestClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 90}                            0.074508                                          0.059202  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 13  RandomForestClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 40}                            0.071847                                          0.097310  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 19  RandomForestClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, grandTota...      {'criterion': 'gini', 'n_estimators': 85}                            0.071847                                          0.088066  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 32  RandomForestClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 95}                            0.066525                                          0.092217  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 33  RandomForestClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 150}                            0.066525                                          0.106367  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 28  RandomForestClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...      {'criterion': 'gini', 'n_estimators': 65}                            0.063864                                          0.096566  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 26  RandomForestClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 130}                            0.063864                                          0.099530  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 38  RandomForestClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 45}                            0.063864                                          0.095302  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 31  RandomForestClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 70}                            0.061203                                          0.112165  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 21  RandomForestClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 30}                            0.061203                                          0.109626  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 23  RandomForestClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 75}                            0.061203                                          0.101539  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 37  RandomForestClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 15}                            0.058542                                          0.091280  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 27  RandomForestClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 20}                            0.055881                                          0.109312  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 36  RandomForestClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 30}                            0.055881                                          0.096886  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 40  RandomForestClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...      {'criterion': 'gini', 'n_estimators': 15}                            0.055881                                          0.103924  (DecisionTreeClassifier(class_weight=None, cri...                       RFECV
# 29  RandomForestClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 80}                            0.053220                                          0.109698  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 35  RandomForestClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, grandTota...   {'criterion': 'entropy', 'n_estimators': 35}                            0.053220                                          0.095709  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 39  RandomForestClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 120}                            0.053220                                          0.104336  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 9   RandomForestClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 105}                            0.045237                                          0.160779  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 34  RandomForestClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'criterion': 'entropy', 'n_estimators': 85}                            0.045237                                          0.125241  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 10  RandomForestClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 100}                            0.039915                                          0.132945  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 6   RandomForestClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 10}                           -0.055881                                          0.178286  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 5   RandomForestClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...       {'criterion': 'gini', 'n_estimators': 5}                           -0.063864                                          0.174134  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 4   RandomForestClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 15}                           -0.069186                                          0.146054  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 8   RandomForestClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 115}                           -0.077169                                          0.149066  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 7   RandomForestClassifier       No Scaling             4  [trustLevel, scannedLineItemsPerSecond, scanne...      {'criterion': 'gini', 'n_estimators': 30}                           -0.079830                                          0.159938  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 3   RandomForestClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 20}                           -0.159659                                          0.208667  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 2   RandomForestClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 30}                           -0.159659                                          0.208667  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest
# 1   RandomForestClassifier       No Scaling             1                                 [scannedLineItems]    {'criterion': 'entropy', 'n_estimators': 5}                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...                         RFE
# 0   RandomForestClassifier       No Scaling             1                                       [trustLevel]    {'criterion': 'entropy', 'n_estimators': 5}                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...                 SelectKBest

# %%
#result_table.to_pickle("result_table_Random_Forest.pkl")
result_table = pd.read_pickle("result_table_Random_Forest.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'grandTotal'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems'
#  'scansWithoutRegistrationPerScannedLineItem' 'secondsPerEuro']
# {'criterion': 'entropy', 'n_estimators': 40}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  0
# True positive:  104
# 520 for 1879 instances in the test set
# 0.2767429483767962 per instance in the test set
