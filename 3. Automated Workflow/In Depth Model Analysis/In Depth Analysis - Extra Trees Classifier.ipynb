# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(ExtraTreesClassifier(),
                 dict(n_estimators = range(1,100),
                      criterion = ['entropy', 'gini']),
                 cv = skf,
                 scoring = my_custom_score)
]           
                 
                 
iterations = 10                
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(ExtraTreesClassifier(),
                 dict(n_estimators = range(1,100),
                      criterion = ['entropy', 'gini']),
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,2):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished ExtraTreesClassifier with No Scaling and 1 features after 133.22 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 2 features after 189.77 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 3 features after 188.26 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 4 features after 238.59 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 5 features after 210.43 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 6 features after 243.69 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 7 features after 275.49 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 8 features after 297.65 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 9 features after 299.84 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 10 features after 298.95 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 11 features after 273.09 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 12 features after 273.75 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 13 features after 283.44 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 14 features after 276.38 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 15 features after 280.47 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 16 features after 302.82 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 17 features after 275.11 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 18 features after 268.9 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 19 features after 210.61 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Finished ExtraTreesClassifier with No Scaling and 20 features after 200.31 seconds
# C:\Users\ahuem\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
#                    Model Data Preparation Feature Count                                           Features                            Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 13  ExtraTreesClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, scansWith...     {'criterion': 'gini', 'n_estimators': 69}                            0.149015                                          0.067366  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 21  ExtraTreesClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 18}                            0.138371                                          0.080357  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 16  ExtraTreesClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 38}                            0.133049                                          0.075975  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 18  ExtraTreesClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...     {'criterion': 'gini', 'n_estimators': 38}                            0.127728                                          0.065613  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 19  ExtraTreesClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 18}                            0.119745                                          0.113658  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 20  ExtraTreesClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 93}                            0.119745                                          0.094438  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 23  ExtraTreesClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 86}                            0.117084                                          0.091290  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 25  ExtraTreesClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 66}                            0.114423                                          0.099429  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 14  ExtraTreesClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...     {'criterion': 'gini', 'n_estimators': 81}                            0.114423                                          0.076066  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 31  ExtraTreesClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 22}                            0.114423                                          0.108643  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 22  ExtraTreesClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...     {'criterion': 'gini', 'n_estimators': 35}                            0.114423                                          0.083114  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 27  ExtraTreesClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 56}                            0.114423                                          0.080329  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 24  ExtraTreesClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 32}                            0.109101                                          0.106687  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 33  ExtraTreesClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 26}                            0.103779                                          0.103986  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 30  ExtraTreesClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 91}                            0.103779                                          0.077276  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 15  ExtraTreesClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 52}                            0.101118                                          0.115643  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 26  ExtraTreesClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...     {'criterion': 'gini', 'n_estimators': 95}                            0.098457                                          0.088891  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 32  ExtraTreesClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 21}                            0.098457                                          0.111503  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 12  ExtraTreesClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 68}                            0.095796                                          0.082354  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 36  ExtraTreesClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 22}                            0.093135                                          0.073409  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 28  ExtraTreesClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 23}                            0.093135                                          0.105241  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 29  ExtraTreesClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 35}                            0.093135                                          0.090730  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 34  ExtraTreesClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 58}                            0.093135                                          0.111019  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 17  ExtraTreesClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, scansWith...     {'criterion': 'gini', 'n_estimators': 48}                            0.090474                                          0.117666  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 35  ExtraTreesClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, grandTota...     {'criterion': 'gini', 'n_estimators': 75}                            0.090474                                          0.085804  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 37  ExtraTreesClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 54}                            0.090474                                          0.112904  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 40  ExtraTreesClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...     {'criterion': 'gini', 'n_estimators': 93}                            0.082491                                          0.100430  (ExtraTreeClassifier(class_weight=None, criter...                       RFECV
# 39  ExtraTreesClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 95}                            0.079830                                          0.066083  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 38  ExtraTreesClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 46}                            0.077169                                          0.091660  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 11  ExtraTreesClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 64}                            0.071847                                          0.139915  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 9   ExtraTreesClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 24}                            0.047898                                          0.106847  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 10  ExtraTreesClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 40}                            0.037254                                          0.140668  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 6   ExtraTreesClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 8}                           -0.039915                                          0.213323  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 4   ExtraTreesClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 48}                           -0.077169                                          0.184136  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 8   ExtraTreesClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 55}                           -0.079830                                          0.228215  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 5   ExtraTreesClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 57}                           -0.082491                                          0.173863  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 7   ExtraTreesClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 6}                           -0.087813                                          0.153077  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 3   ExtraTreesClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.159659                                          0.208667  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 2   ExtraTreesClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.159659                                          0.208667  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 1   ExtraTreesClassifier       No Scaling             1                                 [scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.276743                                          0.011709  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 0   ExtraTreesClassifier       No Scaling             1                                       [trustLevel]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.276743                                          0.011709  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                    Model Data Preparation Feature Count                                           Features                            Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 13  ExtraTreesClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, scansWith...     {'criterion': 'gini', 'n_estimators': 69}                            0.149015                                          0.067366  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 21  ExtraTreesClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 18}                            0.138371                                          0.080357  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 16  ExtraTreesClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 38}                            0.133049                                          0.075975  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 18  ExtraTreesClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...     {'criterion': 'gini', 'n_estimators': 38}                            0.127728                                          0.065613  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 19  ExtraTreesClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 18}                            0.119745                                          0.113658  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 20  ExtraTreesClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 93}                            0.119745                                          0.094438  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 23  ExtraTreesClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 86}                            0.117084                                          0.091290  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 25  ExtraTreesClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 66}                            0.114423                                          0.099429  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 14  ExtraTreesClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...     {'criterion': 'gini', 'n_estimators': 81}                            0.114423                                          0.076066  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 31  ExtraTreesClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 22}                            0.114423                                          0.108643  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 22  ExtraTreesClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...     {'criterion': 'gini', 'n_estimators': 35}                            0.114423                                          0.083114  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 27  ExtraTreesClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 56}                            0.114423                                          0.080329  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 24  ExtraTreesClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 32}                            0.109101                                          0.106687  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 33  ExtraTreesClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 26}                            0.103779                                          0.103986  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 30  ExtraTreesClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 91}                            0.103779                                          0.077276  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 15  ExtraTreesClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 52}                            0.101118                                          0.115643  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 26  ExtraTreesClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...     {'criterion': 'gini', 'n_estimators': 95}                            0.098457                                          0.088891  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 32  ExtraTreesClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 21}                            0.098457                                          0.111503  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 12  ExtraTreesClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 68}                            0.095796                                          0.082354  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 36  ExtraTreesClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 22}                            0.093135                                          0.073409  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 28  ExtraTreesClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 23}                            0.093135                                          0.105241  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 29  ExtraTreesClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 35}                            0.093135                                          0.090730  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 34  ExtraTreesClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'criterion': 'entropy', 'n_estimators': 58}                            0.093135                                          0.111019  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 17  ExtraTreesClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, scansWith...     {'criterion': 'gini', 'n_estimators': 48}                            0.090474                                          0.117666  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 35  ExtraTreesClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, grandTota...     {'criterion': 'gini', 'n_estimators': 75}                            0.090474                                          0.085804  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 37  ExtraTreesClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 54}                            0.090474                                          0.112904  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 40  ExtraTreesClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...     {'criterion': 'gini', 'n_estimators': 93}                            0.082491                                          0.100430  (ExtraTreeClassifier(class_weight=None, criter...                       RFECV
# 39  ExtraTreesClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 95}                            0.079830                                          0.066083  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 38  ExtraTreesClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'criterion': 'entropy', 'n_estimators': 46}                            0.077169                                          0.091660  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 11  ExtraTreesClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 64}                            0.071847                                          0.139915  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 9   ExtraTreesClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 24}                            0.047898                                          0.106847  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 10  ExtraTreesClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 40}                            0.037254                                          0.140668  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 6   ExtraTreesClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 8}                           -0.039915                                          0.213323  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 4   ExtraTreesClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 48}                           -0.077169                                          0.184136  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 8   ExtraTreesClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'criterion': 'entropy', 'n_estimators': 55}                           -0.079830                                          0.228215  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 5   ExtraTreesClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...     {'criterion': 'gini', 'n_estimators': 57}                           -0.082491                                          0.173863  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 7   ExtraTreesClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...      {'criterion': 'gini', 'n_estimators': 6}                           -0.087813                                          0.153077  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 3   ExtraTreesClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.159659                                          0.208667  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 2   ExtraTreesClassifier       No Scaling             2                     [trustLevel, scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.159659                                          0.208667  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest
# 1   ExtraTreesClassifier       No Scaling             1                                 [scannedLineItems]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.276743                                          0.011709  (ExtraTreeClassifier(class_weight=None, criter...                         RFE
# 0   ExtraTreesClassifier       No Scaling             1                                       [trustLevel]   {'criterion': 'entropy', 'n_estimators': 1}                           -0.276743                                          0.011709  (ExtraTreeClassifier(class_weight=None, criter...                 SelectKBest

# %%
#result_table.to_pickle("result_table_Extra_Trees.pkl")
result_table = pd.read_pickle("result_table_Extra_Trees.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=69, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)
# ['trustLevel' 'totalScanTimeInSeconds' 'scansWithoutRegistration'
#  'scannedLineItemsPerSecond' 'lineItemVoidsPerPosition' 'scannedLineItems'
#  'scansWithoutRegistrationPerScannedLineItem']
# {'criterion': 'gini', 'n_estimators': 69}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  0
# True positive:  104
# 520 for 1879 instances in the test set
# 0.2767429483767962 per instance in the test set
