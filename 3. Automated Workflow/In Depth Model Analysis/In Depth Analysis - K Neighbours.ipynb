# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.neighbors.classification import KNeighborsClassifier
from sklearn.model_selection import KFold

skf = StratifiedKFold(n_splits=10)
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(KNeighborsClassifier(), 
                 dict(
                     n_neighbors = [1, 3, 5, 10, 15],
                     weights = ['uniform', 'distance'],
                     p = [1, 2, 3]
                 ),
                 cv = skf,
                 scoring = my_custom_score,
                 n_jobs=4)
]           
                 
                 
iterations = 10                 
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(KNeighborsClassifier(), 
                 dict(
                     n_neighbors = [1, 3, 5, 10, 15],
                     weights = ['uniform', 'distance'],
                     p = [1, 2, 3]
                 ),
                 cv = skf,
                 scoring = my_custom_score,
                 n_iter = iterations, 
                 n_jobs=4)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished KNeighborsClassifier with No Scaling and 1 features after 2.93 seconds
# Finished KNeighborsClassifier with No Scaling and 2 features after 1.74 seconds
# Finished KNeighborsClassifier with No Scaling and 3 features after 1.97 seconds
# Finished KNeighborsClassifier with No Scaling and 4 features after 1.91 seconds
# Finished KNeighborsClassifier with No Scaling and 5 features after 1.99 seconds
# Finished KNeighborsClassifier with No Scaling and 6 features after 2.06 seconds
# Finished KNeighborsClassifier with No Scaling and 7 features after 2.54 seconds
# Finished KNeighborsClassifier with No Scaling and 8 features after 2.62 seconds
# Finished KNeighborsClassifier with No Scaling and 9 features after 3.05 seconds
# Finished KNeighborsClassifier with No Scaling and 10 features after 3.23 seconds
# Finished KNeighborsClassifier with No Scaling and 11 features after 3.45 seconds
# Finished KNeighborsClassifier with No Scaling and 12 features after 3.57 seconds
# Finished KNeighborsClassifier with No Scaling and 13 features after 3.77 seconds
# Finished KNeighborsClassifier with No Scaling and 14 features after 3.84 seconds
# Finished KNeighborsClassifier with No Scaling and 15 features after 4.0 seconds
# Finished KNeighborsClassifier with No Scaling and 16 features after 5.75 seconds
# Finished KNeighborsClassifier with No Scaling and 17 features after 4.99 seconds
# Finished KNeighborsClassifier with No Scaling and 18 features after 5.14 seconds
# Finished KNeighborsClassifier with No Scaling and 19 features after 6.08 seconds
# Finished KNeighborsClassifier with No Scaling and 20 features after 5.3 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 1 features after 2.02 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 2 features after 1.75 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 3 features after 1.84 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 4 features after 1.89 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 5 features after 1.98 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 6 features after 2.07 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 7 features after 2.19 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 8 features after 2.61 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 9 features after 2.79 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 10 features after 2.86 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 11 features after 3.33 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 12 features after 3.49 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 13 features after 3.62 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 14 features after 3.75 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 15 features after 3.96 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 16 features after 4.79 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 17 features after 4.77 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 18 features after 5.22 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 19 features after 5.18 seconds
# Finished KNeighborsClassifier with MinMaxScaler and 20 features after 5.04 seconds
# Finished KNeighborsClassifier with StandardScaler and 1 features after 2.0 seconds
# Finished KNeighborsClassifier with StandardScaler and 2 features after 1.76 seconds
# Finished KNeighborsClassifier with StandardScaler and 3 features after 1.81 seconds
# Finished KNeighborsClassifier with StandardScaler and 4 features after 1.89 seconds
# Finished KNeighborsClassifier with StandardScaler and 5 features after 2.04 seconds
# Finished KNeighborsClassifier with StandardScaler and 6 features after 2.4 seconds
# Finished KNeighborsClassifier with StandardScaler and 7 features after 2.48 seconds
# Finished KNeighborsClassifier with StandardScaler and 8 features after 2.58 seconds
# Finished KNeighborsClassifier with StandardScaler and 9 features after 2.71 seconds
# Finished KNeighborsClassifier with StandardScaler and 10 features after 2.82 seconds
# Finished KNeighborsClassifier with StandardScaler and 11 features after 3.35 seconds
# Finished KNeighborsClassifier with StandardScaler and 12 features after 2.83 seconds
# Finished KNeighborsClassifier with StandardScaler and 13 features after 3.23 seconds
# Finished KNeighborsClassifier with StandardScaler and 14 features after 3.84 seconds
# Finished KNeighborsClassifier with StandardScaler and 15 features after 3.24 seconds
# Finished KNeighborsClassifier with StandardScaler and 16 features after 5.7 seconds
# Finished KNeighborsClassifier with StandardScaler and 17 features after 5.0 seconds
# Finished KNeighborsClassifier with StandardScaler and 18 features after 5.17 seconds
# Finished KNeighborsClassifier with StandardScaler and 19 features after 5.11 seconds
# Finished KNeighborsClassifier with StandardScaler and 20 features after 5.26 seconds
# Finished KNeighborsClassifier with LogScaler and 1 features after 2.02 seconds
# Finished KNeighborsClassifier with LogScaler and 2 features after 1.75 seconds
# Finished KNeighborsClassifier with LogScaler and 3 features after 2.05 seconds
# Finished KNeighborsClassifier with LogScaler and 4 features after 2.21 seconds
# Finished KNeighborsClassifier with LogScaler and 5 features after 2.47 seconds
# Finished KNeighborsClassifier with LogScaler and 6 features after 3.05 seconds
# Finished KNeighborsClassifier with LogScaler and 7 features after 2.58 seconds
# Finished KNeighborsClassifier with LogScaler and 8 features after 3.39 seconds
# Finished KNeighborsClassifier with LogScaler and 9 features after 3.55 seconds
# Finished KNeighborsClassifier with LogScaler and 10 features after 3.77 seconds
# Finished KNeighborsClassifier with LogScaler and 11 features after 4.0 seconds
# Finished KNeighborsClassifier with LogScaler and 12 features after 4.84 seconds
# Finished KNeighborsClassifier with LogScaler and 13 features after 5.2 seconds
# Finished KNeighborsClassifier with LogScaler and 14 features after 5.32 seconds
# Finished KNeighborsClassifier with LogScaler and 15 features after 5.52 seconds
# Finished KNeighborsClassifier with LogScaler and 16 features after 5.92 seconds
# Finished KNeighborsClassifier with LogScaler and 17 features after 4.95 seconds
# Finished KNeighborsClassifier with LogScaler and 18 features after 5.18 seconds
# Finished KNeighborsClassifier with LogScaler and 19 features after 5.21 seconds
# Finished KNeighborsClassifier with LogScaler and 20 features after 5.21 seconds
#                    Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 65  KNeighborsClassifier        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'n_neighbors': 10, 'p': 2, 'weights': 'distan...                           -0.156998                                          0.258287  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 62  KNeighborsClassifier        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.159659                                          0.239428  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 21  KNeighborsClassifier     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 41  KNeighborsClassifier   StandardScaler             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 1   KNeighborsClassifier       No Scaling             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 61  KNeighborsClassifier        LogScaler             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 64  KNeighborsClassifier        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.167642                                          0.222894  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 63  KNeighborsClassifier        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.191591                                          0.220022  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 22  KNeighborsClassifier     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 15, 'p': 1, 'weights': 'distan...                           -0.268760                                          0.034757  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 42  KNeighborsClassifier   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 15, 'p': 1, 'weights': 'distan...                           -0.268760                                          0.034757  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 2   KNeighborsClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 15, 'p': 1, 'weights': 'distan...                           -0.268760                                          0.034757  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 71  KNeighborsClassifier        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 56  KNeighborsClassifier   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 78  KNeighborsClassifier        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 44  KNeighborsClassifier   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 45  KNeighborsClassifier   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 46  KNeighborsClassifier   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 47  KNeighborsClassifier   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 48  KNeighborsClassifier   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 49  KNeighborsClassifier   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 50  KNeighborsClassifier   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 51  KNeighborsClassifier   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 52  KNeighborsClassifier   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 53  KNeighborsClassifier   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 54  KNeighborsClassifier   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 55  KNeighborsClassifier   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 57  KNeighborsClassifier   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 70  KNeighborsClassifier        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 58  KNeighborsClassifier   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 59  KNeighborsClassifier   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 60  KNeighborsClassifier        LogScaler             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 77  KNeighborsClassifier        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 43  KNeighborsClassifier   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 76  KNeighborsClassifier        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 75  KNeighborsClassifier        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 74  KNeighborsClassifier        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 73  KNeighborsClassifier        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 72  KNeighborsClassifier        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 66  KNeighborsClassifier        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 67  KNeighborsClassifier        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 68  KNeighborsClassifier        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 69  KNeighborsClassifier        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 0   KNeighborsClassifier       No Scaling             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 40  KNeighborsClassifier   StandardScaler             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 39  KNeighborsClassifier     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 38  KNeighborsClassifier     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 17  KNeighborsClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 16  KNeighborsClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 15  KNeighborsClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 14  KNeighborsClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 13  KNeighborsClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 12  KNeighborsClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 11  KNeighborsClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 10  KNeighborsClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 9   KNeighborsClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 8   KNeighborsClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 7   KNeighborsClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 6   KNeighborsClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 5   KNeighborsClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 4   KNeighborsClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 3   KNeighborsClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 18  KNeighborsClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 19  KNeighborsClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 20  KNeighborsClassifier     MinMaxScaler             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 31  KNeighborsClassifier     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 37  KNeighborsClassifier     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 36  KNeighborsClassifier     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 35  KNeighborsClassifier     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 34  KNeighborsClassifier     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 33  KNeighborsClassifier     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 32  KNeighborsClassifier     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 30  KNeighborsClassifier     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 23  KNeighborsClassifier     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 29  KNeighborsClassifier     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 28  KNeighborsClassifier     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 27  KNeighborsClassifier     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 26  KNeighborsClassifier     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 25  KNeighborsClassifier     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 24  KNeighborsClassifier     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 79  KNeighborsClassifier        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                    Model Data Preparation Feature Count                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 65  KNeighborsClassifier        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...  {'n_neighbors': 10, 'p': 2, 'weights': 'distan...                           -0.156998                                          0.258287  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 62  KNeighborsClassifier        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.159659                                          0.239428  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 21  KNeighborsClassifier     MinMaxScaler             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 41  KNeighborsClassifier   StandardScaler             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 1   KNeighborsClassifier       No Scaling             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 61  KNeighborsClassifier        LogScaler             2                     [trustLevel, scannedLineItems]  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.164981                                          0.203795  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 64  KNeighborsClassifier        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.167642                                          0.222894  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 63  KNeighborsClassifier        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.191591                                          0.220022  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 22  KNeighborsClassifier     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 15, 'p': 1, 'weights': 'distan...                           -0.268760                                          0.034757  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 42  KNeighborsClassifier   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 15, 'p': 1, 'weights': 'distan...                           -0.268760                                          0.034757  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 2   KNeighborsClassifier       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 15, 'p': 1, 'weights': 'distan...                           -0.268760                                          0.034757  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 71  KNeighborsClassifier        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 56  KNeighborsClassifier   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 78  KNeighborsClassifier        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 44  KNeighborsClassifier   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 45  KNeighborsClassifier   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 46  KNeighborsClassifier   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 47  KNeighborsClassifier   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 48  KNeighborsClassifier   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 49  KNeighborsClassifier   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 50  KNeighborsClassifier   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 51  KNeighborsClassifier   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 52  KNeighborsClassifier   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 53  KNeighborsClassifier   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 54  KNeighborsClassifier   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 55  KNeighborsClassifier   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 57  KNeighborsClassifier   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 70  KNeighborsClassifier        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 58  KNeighborsClassifier   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 59  KNeighborsClassifier   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 60  KNeighborsClassifier        LogScaler             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 77  KNeighborsClassifier        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 43  KNeighborsClassifier   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 76  KNeighborsClassifier        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 75  KNeighborsClassifier        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 74  KNeighborsClassifier        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 73  KNeighborsClassifier        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 72  KNeighborsClassifier        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 66  KNeighborsClassifier        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 67  KNeighborsClassifier        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 68  KNeighborsClassifier        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 69  KNeighborsClassifier        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 0   KNeighborsClassifier       No Scaling             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 40  KNeighborsClassifier   StandardScaler             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 39  KNeighborsClassifier     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 38  KNeighborsClassifier     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 17  KNeighborsClassifier       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 16  KNeighborsClassifier       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 15  KNeighborsClassifier       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 14  KNeighborsClassifier       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 13  KNeighborsClassifier       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 12  KNeighborsClassifier       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 11  KNeighborsClassifier       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 10  KNeighborsClassifier       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 9   KNeighborsClassifier       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 8   KNeighborsClassifier       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 7   KNeighborsClassifier       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 6   KNeighborsClassifier       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 5   KNeighborsClassifier       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 4   KNeighborsClassifier       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 3   KNeighborsClassifier       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 18  KNeighborsClassifier       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 19  KNeighborsClassifier       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 20  KNeighborsClassifier     MinMaxScaler             1                                       [trustLevel]  {'n_neighbors': 15, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 31  KNeighborsClassifier     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 37  KNeighborsClassifier     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 36  KNeighborsClassifier     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 35  KNeighborsClassifier     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 34  KNeighborsClassifier     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 33  KNeighborsClassifier     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 32  KNeighborsClassifier     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 30  KNeighborsClassifier     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 23  KNeighborsClassifier     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 29  KNeighborsClassifier     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 28  KNeighborsClassifier     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 27  KNeighborsClassifier     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 26  KNeighborsClassifier     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 25  KNeighborsClassifier     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 24  KNeighborsClassifier     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest
# 79  KNeighborsClassifier        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}                           -0.276743                                          0.011709  KNeighborsClassifier(algorithm='auto', leaf_si...                 SelectKBest

# %%
#result_table.to_pickle("result_table_K_Neighbours.pkl")
result_table = pd.read_pickle("result_table_K_Neighbours.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='distance')
# ['trustLevel' 'lineItemVoidsPerPosition' 'scannedLineItems'
#  'pricePerScannedLineItem' 'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem']
# {'n_neighbors': 10, 'p': 2, 'weights': 'distance'}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  0
# True positive:  104
# 520 for 1879 instances in the test set
# 0.2767429483767962 per instance in the test set
