# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %%
print(train.fraud.value_counts())
print(train.fraud.value_counts() / len(train))
# Out:
# 0    1775
# 1     104
# Name: fraud, dtype: int64
# 0    0.944651
# 1    0.055349
# Name: fraud, dtype: float64

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
    GridSearchCV(LinearDiscriminantAnalysis(),
                 dict(solver  = ['svd', 'lsqr', 'eigen'],
                      n_components = range(1,20)),
                 cv = skf,
                 scoring = my_custom_score)
]           
                 
                 
iterations = 10                
               
model_tuning_factory_randomized = [
    RandomizedSearchCV(LinearDiscriminantAnalysis(),
                 dict(solver  = ['svd', 'lsqr', 'eigen']),
                 cv = skf,
                 scoring = my_custom_score,
                      n_iter  = iterations)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


# Scaling is not relevant for Decision Trees
for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished LinearDiscriminantAnalysis with No Scaling and 1 features after 4.86 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 2 features after 5.46 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 3 features after 4.95 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 4 features after 5.26 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 5 features after 5.6 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 6 features after 5.84 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 7 features after 5.9 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 8 features after 6.31 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 9 features after 6.23 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 10 features after 6.15 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 11 features after 6.32 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 12 features after 6.32 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 13 features after 6.52 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 14 features after 6.93 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 15 features after 7.1 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 16 features after 6.97 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 17 features after 6.94 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 18 features after 7.31 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 19 features after 7.57 seconds
# Finished LinearDiscriminantAnalysis with No Scaling and 20 features after 8.05 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 1 features after 4.43 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 2 features after 5.29 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 3 features after 4.97 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 4 features after 5.29 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 5 features after 7.03 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 6 features after 5.84 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 7 features after 8.34 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 8 features after 8.82 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 9 features after 9.04 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 10 features after 9.1 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 11 features after 9.29 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 12 features after 7.03 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 13 features after 6.27 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 14 features after 6.42 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 15 features after 6.87 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 16 features after 7.22 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 17 features after 7.24 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 18 features after 7.36 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 19 features after 7.26 seconds
# Finished LinearDiscriminantAnalysis with MinMaxScaler and 20 features after 7.21 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 1 features after 4.69 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 2 features after 5.42 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 3 features after 5.19 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 4 features after 5.43 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 5 features after 5.41 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 6 features after 5.49 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 7 features after 5.54 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 8 features after 5.65 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 9 features after 6.18 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 10 features after 5.87 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 11 features after 6.07 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 12 features after 6.52 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 13 features after 6.68 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 14 features after 6.6 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 15 features after 6.97 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 16 features after 6.97 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 17 features after 7.14 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 18 features after 7.54 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 19 features after 7.24 seconds
# Finished LinearDiscriminantAnalysis with StandardScaler and 20 features after 7.56 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 1 features after 4.52 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 2 features after 5.12 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 3 features after 5.21 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 4 features after 5.18 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 5 features after 5.29 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 6 features after 5.55 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 7 features after 5.93 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 8 features after 6.03 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 9 features after 6.0 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 10 features after 6.45 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 11 features after 6.31 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 12 features after 6.42 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 13 features after 6.68 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 14 features after 7.04 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 15 features after 6.71 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 16 features after 6.73 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 17 features after 6.99 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 18 features after 7.21 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 19 features after 7.26 seconds
# Finished LinearDiscriminantAnalysis with LogScaler and 20 features after 7.72 seconds
#                           Model Data Preparation Feature Count                                           Features                     Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 24   LinearDiscriminantAnalysis       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 22   LinearDiscriminantAnalysis       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 20   LinearDiscriminantAnalysis       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 106  LinearDiscriminantAnalysis   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 61   LinearDiscriminantAnalysis     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 104  LinearDiscriminantAnalysis   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 63   LinearDiscriminantAnalysis     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 102  LinearDiscriminantAnalysis   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 143  LinearDiscriminantAnalysis        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 65   LinearDiscriminantAnalysis     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 98   LinearDiscriminantAnalysis   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 16   LinearDiscriminantAnalysis       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 57   LinearDiscriminantAnalysis     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 59   LinearDiscriminantAnalysis     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 100  LinearDiscriminantAnalysis   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 18   LinearDiscriminantAnalysis       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 145  LinearDiscriminantAnalysis        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.077169                                          0.102153  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 96   LinearDiscriminantAnalysis   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.079830                                          0.120915  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 14   LinearDiscriminantAnalysis       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.079830                                          0.120915  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 55   LinearDiscriminantAnalysis     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.079830                                          0.120915  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 147  LinearDiscriminantAnalysis        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 111  LinearDiscriminantAnalysis   StandardScaler            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 70   LinearDiscriminantAnalysis     MinMaxScaler            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 149  LinearDiscriminantAnalysis        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 29   LinearDiscriminantAnalysis       No Scaling            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 151  LinearDiscriminantAnalysis        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 153  LinearDiscriminantAnalysis        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 152  LinearDiscriminantAnalysis        LogScaler            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 27   LinearDiscriminantAnalysis       No Scaling            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 68   LinearDiscriminantAnalysis     MinMaxScaler            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 109  LinearDiscriminantAnalysis   StandardScaler            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 141  LinearDiscriminantAnalysis        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.085152                                          0.125437  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 150  LinearDiscriminantAnalysis        LogScaler            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 139  LinearDiscriminantAnalysis        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.097471  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 49   LinearDiscriminantAnalysis     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.096032  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 90   LinearDiscriminantAnalysis   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.096032  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 8    LinearDiscriminantAnalysis       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.096032  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 108  LinearDiscriminantAnalysis   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.164486  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 107  LinearDiscriminantAnalysis   StandardScaler            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 62   LinearDiscriminantAnalysis     MinMaxScaler            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 105  LinearDiscriminantAnalysis   StandardScaler            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 146  LinearDiscriminantAnalysis        LogScaler            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 103  LinearDiscriminantAnalysis   StandardScaler            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 64   LinearDiscriminantAnalysis     MinMaxScaler            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 66   LinearDiscriminantAnalysis     MinMaxScaler            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 148  LinearDiscriminantAnalysis        LogScaler            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 144  LinearDiscriminantAnalysis        LogScaler            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 67   LinearDiscriminantAnalysis     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.164486  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 21   LinearDiscriminantAnalysis       No Scaling            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 23   LinearDiscriminantAnalysis       No Scaling            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 25   LinearDiscriminantAnalysis       No Scaling            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 26   LinearDiscriminantAnalysis       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.164486  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 101  LinearDiscriminantAnalysis   StandardScaler            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 19   LinearDiscriminantAnalysis       No Scaling            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 142  LinearDiscriminantAnalysis        LogScaler            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 94   LinearDiscriminantAnalysis   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 140  LinearDiscriminantAnalysis        LogScaler             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 99   LinearDiscriminantAnalysis   StandardScaler             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 12   LinearDiscriminantAnalysis       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 17   LinearDiscriminantAnalysis       No Scaling             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 58   LinearDiscriminantAnalysis     MinMaxScaler             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 53   LinearDiscriminantAnalysis     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 137  LinearDiscriminantAnalysis        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 135  LinearDiscriminantAnalysis        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 60   LinearDiscriminantAnalysis     MinMaxScaler            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 10   LinearDiscriminantAnalysis       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.098457                                          0.096050  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 51   LinearDiscriminantAnalysis     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.098457                                          0.096050  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 92   LinearDiscriminantAnalysis   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.098457                                          0.096050  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 74   LinearDiscriminantAnalysis     MinMaxScaler            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 156  LinearDiscriminantAnalysis        LogScaler            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 115  LinearDiscriminantAnalysis   StandardScaler            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 33   LinearDiscriminantAnalysis       No Scaling            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 88   LinearDiscriminantAnalysis   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.085440  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 47   LinearDiscriminantAnalysis     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.085440  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 73   LinearDiscriminantAnalysis     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 32   LinearDiscriminantAnalysis       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 6    LinearDiscriminantAnalysis       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.085440  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 155  LinearDiscriminantAnalysis        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 114  LinearDiscriminantAnalysis   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 28   LinearDiscriminantAnalysis       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 112  LinearDiscriminantAnalysis   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 113  LinearDiscriminantAnalysis   StandardScaler            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 110  LinearDiscriminantAnalysis   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 30   LinearDiscriminantAnalysis       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 154  LinearDiscriminantAnalysis        LogScaler            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 72   LinearDiscriminantAnalysis     MinMaxScaler            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 71   LinearDiscriminantAnalysis     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 31   LinearDiscriminantAnalysis       No Scaling            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 69   LinearDiscriminantAnalysis     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 45   LinearDiscriminantAnalysis     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.083797  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 119  LinearDiscriminantAnalysis   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 4    LinearDiscriminantAnalysis       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.083797  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 160  LinearDiscriminantAnalysis        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 158  LinearDiscriminantAnalysis        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 37   LinearDiscriminantAnalysis       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 157  LinearDiscriminantAnalysis        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 116  LinearDiscriminantAnalysis   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 35   LinearDiscriminantAnalysis       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 34   LinearDiscriminantAnalysis       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 117  LinearDiscriminantAnalysis   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 75   LinearDiscriminantAnalysis     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 76   LinearDiscriminantAnalysis     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 86   LinearDiscriminantAnalysis   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.083797  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 78   LinearDiscriminantAnalysis     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 159  LinearDiscriminantAnalysis        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 118  LinearDiscriminantAnalysis   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 77   LinearDiscriminantAnalysis     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 36   LinearDiscriminantAnalysis       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 122  LinearDiscriminantAnalysis   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 121  LinearDiscriminantAnalysis   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 120  LinearDiscriminantAnalysis   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 163  LinearDiscriminantAnalysis        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 161  LinearDiscriminantAnalysis        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 81   LinearDiscriminantAnalysis     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 80   LinearDiscriminantAnalysis     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 79   LinearDiscriminantAnalysis     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 162  LinearDiscriminantAnalysis        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 40   LinearDiscriminantAnalysis       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 39   LinearDiscriminantAnalysis       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 38   LinearDiscriminantAnalysis       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 131  LinearDiscriminantAnalysis        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.156998                                          0.113541  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 97   LinearDiscriminantAnalysis   StandardScaler             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 138  LinearDiscriminantAnalysis        LogScaler             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 15   LinearDiscriminantAnalysis       No Scaling             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 56   LinearDiscriminantAnalysis     MinMaxScaler             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 127  LinearDiscriminantAnalysis        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...   {'n_components': 1, 'solver': 'svd'}                           -0.162320                                          0.114732  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 129  LinearDiscriminantAnalysis        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...   {'n_components': 1, 'solver': 'svd'}                           -0.162320                                          0.114732  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 133  LinearDiscriminantAnalysis        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.162320                                          0.114732  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 84   LinearDiscriminantAnalysis   StandardScaler             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 125  LinearDiscriminantAnalysis        LogScaler             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 43   LinearDiscriminantAnalysis     MinMaxScaler             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 2    LinearDiscriminantAnalysis       No Scaling             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 136  LinearDiscriminantAnalysis        LogScaler             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 134  LinearDiscriminantAnalysis        LogScaler             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 0    LinearDiscriminantAnalysis       No Scaling             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 132  LinearDiscriminantAnalysis        LogScaler             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 52   LinearDiscriminantAnalysis     MinMaxScaler             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 3    LinearDiscriminantAnalysis       No Scaling             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 5    LinearDiscriminantAnalysis       No Scaling             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 7    LinearDiscriminantAnalysis       No Scaling             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 9    LinearDiscriminantAnalysis       No Scaling             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 11   LinearDiscriminantAnalysis       No Scaling             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 13   LinearDiscriminantAnalysis       No Scaling             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 41   LinearDiscriminantAnalysis     MinMaxScaler             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 42   LinearDiscriminantAnalysis     MinMaxScaler             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 44   LinearDiscriminantAnalysis     MinMaxScaler             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 46   LinearDiscriminantAnalysis     MinMaxScaler             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 48   LinearDiscriminantAnalysis     MinMaxScaler             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 50   LinearDiscriminantAnalysis     MinMaxScaler             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 54   LinearDiscriminantAnalysis     MinMaxScaler             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 130  LinearDiscriminantAnalysis        LogScaler             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 1    LinearDiscriminantAnalysis       No Scaling             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 83   LinearDiscriminantAnalysis   StandardScaler             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 85   LinearDiscriminantAnalysis   StandardScaler             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 87   LinearDiscriminantAnalysis   StandardScaler             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 89   LinearDiscriminantAnalysis   StandardScaler             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 91   LinearDiscriminantAnalysis   StandardScaler             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 93   LinearDiscriminantAnalysis   StandardScaler             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 95   LinearDiscriminantAnalysis   StandardScaler             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 123  LinearDiscriminantAnalysis        LogScaler             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 124  LinearDiscriminantAnalysis        LogScaler             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 126  LinearDiscriminantAnalysis        LogScaler             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 128  LinearDiscriminantAnalysis        LogScaler             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 82   LinearDiscriminantAnalysis   StandardScaler             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                           Model Data Preparation Feature Count                                           Features                     Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model Feature Selection Technique
# 24   LinearDiscriminantAnalysis       No Scaling            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 22   LinearDiscriminantAnalysis       No Scaling            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 20   LinearDiscriminantAnalysis       No Scaling            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 106  LinearDiscriminantAnalysis   StandardScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 61   LinearDiscriminantAnalysis     MinMaxScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 104  LinearDiscriminantAnalysis   StandardScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 63   LinearDiscriminantAnalysis     MinMaxScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 102  LinearDiscriminantAnalysis   StandardScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 143  LinearDiscriminantAnalysis        LogScaler            11  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 65   LinearDiscriminantAnalysis     MinMaxScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'n_components': 1, 'solver': 'lsqr'}                           -0.063864                                          0.112533  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 98   LinearDiscriminantAnalysis   StandardScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 16   LinearDiscriminantAnalysis       No Scaling             9  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 57   LinearDiscriminantAnalysis     MinMaxScaler             9  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 59   LinearDiscriminantAnalysis     MinMaxScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 100  LinearDiscriminantAnalysis   StandardScaler            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 18   LinearDiscriminantAnalysis       No Scaling            10  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.069186                                          0.113139  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 145  LinearDiscriminantAnalysis        LogScaler            12  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.077169                                          0.102153  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 96   LinearDiscriminantAnalysis   StandardScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.079830                                          0.120915  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 14   LinearDiscriminantAnalysis       No Scaling             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.079830                                          0.120915  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 55   LinearDiscriminantAnalysis     MinMaxScaler             8  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.079830                                          0.120915  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 147  LinearDiscriminantAnalysis        LogScaler            13  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 111  LinearDiscriminantAnalysis   StandardScaler            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 70   LinearDiscriminantAnalysis     MinMaxScaler            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 149  LinearDiscriminantAnalysis        LogScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 29   LinearDiscriminantAnalysis       No Scaling            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 151  LinearDiscriminantAnalysis        LogScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 153  LinearDiscriminantAnalysis        LogScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.102129  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 152  LinearDiscriminantAnalysis        LogScaler            15  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.082491                                          0.111338  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 27   LinearDiscriminantAnalysis       No Scaling            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 68   LinearDiscriminantAnalysis     MinMaxScaler            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 109  LinearDiscriminantAnalysis   StandardScaler            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 141  LinearDiscriminantAnalysis        LogScaler            10  [trustLevel, totalScanTimeInSeconds, scansWith...  {'n_components': 1, 'solver': 'lsqr'}                           -0.085152                                          0.125437  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 150  LinearDiscriminantAnalysis        LogScaler            14  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.085152                                          0.088214  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 139  LinearDiscriminantAnalysis        LogScaler             9  [trustLevel, totalScanTimeInSeconds, valuePerS...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.097471  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 49   LinearDiscriminantAnalysis     MinMaxScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.096032  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 90   LinearDiscriminantAnalysis   StandardScaler             5  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.096032  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 8    LinearDiscriminantAnalysis       No Scaling             5  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.087813                                          0.096032  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 108  LinearDiscriminantAnalysis   StandardScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.164486  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 107  LinearDiscriminantAnalysis   StandardScaler            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 62   LinearDiscriminantAnalysis     MinMaxScaler            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 105  LinearDiscriminantAnalysis   StandardScaler            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 146  LinearDiscriminantAnalysis        LogScaler            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 103  LinearDiscriminantAnalysis   StandardScaler            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 64   LinearDiscriminantAnalysis     MinMaxScaler            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 66   LinearDiscriminantAnalysis     MinMaxScaler            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 148  LinearDiscriminantAnalysis        LogScaler            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 144  LinearDiscriminantAnalysis        LogScaler            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 67   LinearDiscriminantAnalysis     MinMaxScaler            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.164486  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 21   LinearDiscriminantAnalysis       No Scaling            11  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 23   LinearDiscriminantAnalysis       No Scaling            12  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 25   LinearDiscriminantAnalysis       No Scaling            13  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.089293  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 26   LinearDiscriminantAnalysis       No Scaling            14  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.090474                                          0.164486  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 101  LinearDiscriminantAnalysis   StandardScaler            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 19   LinearDiscriminantAnalysis       No Scaling            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 142  LinearDiscriminantAnalysis        LogScaler            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 94   LinearDiscriminantAnalysis   StandardScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 140  LinearDiscriminantAnalysis        LogScaler             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 99   LinearDiscriminantAnalysis   StandardScaler             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 12   LinearDiscriminantAnalysis       No Scaling             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 17   LinearDiscriminantAnalysis       No Scaling             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 58   LinearDiscriminantAnalysis     MinMaxScaler             9  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 53   LinearDiscriminantAnalysis     MinMaxScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 137  LinearDiscriminantAnalysis        LogScaler             8  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 135  LinearDiscriminantAnalysis        LogScaler             7  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.093927  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 60   LinearDiscriminantAnalysis     MinMaxScaler            10  [trustLevel, scansWithoutRegistration, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.093135                                          0.098459  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 10   LinearDiscriminantAnalysis       No Scaling             6  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.098457                                          0.096050  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 51   LinearDiscriminantAnalysis     MinMaxScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.098457                                          0.096050  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 92   LinearDiscriminantAnalysis   StandardScaler             6  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.098457                                          0.096050  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 74   LinearDiscriminantAnalysis     MinMaxScaler            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 156  LinearDiscriminantAnalysis        LogScaler            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 115  LinearDiscriminantAnalysis   StandardScaler            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 33   LinearDiscriminantAnalysis       No Scaling            17  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.101118                                          0.120584  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 88   LinearDiscriminantAnalysis   StandardScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.085440  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 47   LinearDiscriminantAnalysis     MinMaxScaler             4  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.085440  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 73   LinearDiscriminantAnalysis     MinMaxScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 32   LinearDiscriminantAnalysis       No Scaling            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 6    LinearDiscriminantAnalysis       No Scaling             4  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.085440  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 155  LinearDiscriminantAnalysis        LogScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 114  LinearDiscriminantAnalysis   StandardScaler            17  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.103779                                          0.155303  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 28   LinearDiscriminantAnalysis       No Scaling            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 112  LinearDiscriminantAnalysis   StandardScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 113  LinearDiscriminantAnalysis   StandardScaler            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 110  LinearDiscriminantAnalysis   StandardScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 30   LinearDiscriminantAnalysis       No Scaling            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 154  LinearDiscriminantAnalysis        LogScaler            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 72   LinearDiscriminantAnalysis     MinMaxScaler            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 71   LinearDiscriminantAnalysis     MinMaxScaler            16  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 31   LinearDiscriminantAnalysis       No Scaling            16  [trustLevel, lineItemVoids, scansWithoutRegist...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.130971  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 69   LinearDiscriminantAnalysis     MinMaxScaler            15  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.109101                                          0.154373  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 45   LinearDiscriminantAnalysis     MinMaxScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.083797  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 119  LinearDiscriminantAnalysis   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 4    LinearDiscriminantAnalysis       No Scaling             3  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.083797  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 160  LinearDiscriminantAnalysis        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 158  LinearDiscriminantAnalysis        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 37   LinearDiscriminantAnalysis       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 157  LinearDiscriminantAnalysis        LogScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 116  LinearDiscriminantAnalysis   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 35   LinearDiscriminantAnalysis       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 34   LinearDiscriminantAnalysis       No Scaling            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 117  LinearDiscriminantAnalysis   StandardScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 75   LinearDiscriminantAnalysis     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.156040  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 76   LinearDiscriminantAnalysis     MinMaxScaler            18  [trustLevel, totalScanTimeInSeconds, lineItemV...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 86   LinearDiscriminantAnalysis   StandardScaler             3  [trustLevel, totalScanTimeInSeconds, scannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.083797  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 78   LinearDiscriminantAnalysis     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.117084                                          0.162224  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 159  LinearDiscriminantAnalysis        LogScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 118  LinearDiscriminantAnalysis   StandardScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 77   LinearDiscriminantAnalysis     MinMaxScaler            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 36   LinearDiscriminantAnalysis       No Scaling            19  [trustLevel, totalScanTimeInSeconds, grandTota...  {'n_components': 1, 'solver': 'lsqr'}                           -0.122406                                          0.159143  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 122  LinearDiscriminantAnalysis   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 121  LinearDiscriminantAnalysis   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 120  LinearDiscriminantAnalysis   StandardScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 163  LinearDiscriminantAnalysis        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 161  LinearDiscriminantAnalysis        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 81   LinearDiscriminantAnalysis     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 80   LinearDiscriminantAnalysis     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 79   LinearDiscriminantAnalysis     MinMaxScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 162  LinearDiscriminantAnalysis        LogScaler            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 40   LinearDiscriminantAnalysis       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                       RFECV
# 39   LinearDiscriminantAnalysis       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 38   LinearDiscriminantAnalysis       No Scaling            20  [trustLevel, totalScanTimeInSeconds, grandTota...   {'n_components': 1, 'solver': 'svd'}                           -0.127728                                          0.163741  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 131  LinearDiscriminantAnalysis        LogScaler             5  [trustLevel, lineItemVoidsPerPosition, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.156998                                          0.113541  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 97   LinearDiscriminantAnalysis   StandardScaler             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 138  LinearDiscriminantAnalysis        LogScaler             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 15   LinearDiscriminantAnalysis       No Scaling             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 56   LinearDiscriminantAnalysis     MinMaxScaler             8  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.159659                                          0.146454  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 127  LinearDiscriminantAnalysis        LogScaler             3  [trustLevel, scannedLineItems, pricePerScanned...   {'n_components': 1, 'solver': 'svd'}                           -0.162320                                          0.114732  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 129  LinearDiscriminantAnalysis        LogScaler             4  [trustLevel, scannedLineItems, pricePerScanned...   {'n_components': 1, 'solver': 'svd'}                           -0.162320                                          0.114732  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 133  LinearDiscriminantAnalysis        LogScaler             6  [trustLevel, lineItemVoidsPerPosition, scanned...   {'n_components': 1, 'solver': 'svd'}                           -0.162320                                          0.114732  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 84   LinearDiscriminantAnalysis   StandardScaler             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 125  LinearDiscriminantAnalysis        LogScaler             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 43   LinearDiscriminantAnalysis     MinMaxScaler             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 2    LinearDiscriminantAnalysis       No Scaling             2                     [trustLevel, scannedLineItems]   {'n_components': 1, 'solver': 'svd'}                           -0.204896                                          0.128431  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 136  LinearDiscriminantAnalysis        LogScaler             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 134  LinearDiscriminantAnalysis        LogScaler             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 0    LinearDiscriminantAnalysis       No Scaling             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 132  LinearDiscriminantAnalysis        LogScaler             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 52   LinearDiscriminantAnalysis     MinMaxScaler             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 3    LinearDiscriminantAnalysis       No Scaling             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 5    LinearDiscriminantAnalysis       No Scaling             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 7    LinearDiscriminantAnalysis       No Scaling             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 9    LinearDiscriminantAnalysis       No Scaling             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 11   LinearDiscriminantAnalysis       No Scaling             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 13   LinearDiscriminantAnalysis       No Scaling             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 41   LinearDiscriminantAnalysis     MinMaxScaler             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 42   LinearDiscriminantAnalysis     MinMaxScaler             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 44   LinearDiscriminantAnalysis     MinMaxScaler             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 46   LinearDiscriminantAnalysis     MinMaxScaler             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 48   LinearDiscriminantAnalysis     MinMaxScaler             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 50   LinearDiscriminantAnalysis     MinMaxScaler             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 54   LinearDiscriminantAnalysis     MinMaxScaler             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 130  LinearDiscriminantAnalysis        LogScaler             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 1    LinearDiscriminantAnalysis       No Scaling             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 83   LinearDiscriminantAnalysis   StandardScaler             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 85   LinearDiscriminantAnalysis   StandardScaler             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 87   LinearDiscriminantAnalysis   StandardScaler             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 89   LinearDiscriminantAnalysis   StandardScaler             4  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 91   LinearDiscriminantAnalysis   StandardScaler             5  [trustLevel, scannedLineItemsPerSecond, quanti...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 93   LinearDiscriminantAnalysis   StandardScaler             6  [trustLevel, scannedLineItemsPerSecond, lineIt...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 95   LinearDiscriminantAnalysis   StandardScaler             7  [trustLevel, scannedLineItemsPerSecond, valueP...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 123  LinearDiscriminantAnalysis        LogScaler             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest
# 124  LinearDiscriminantAnalysis        LogScaler             1                   [quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 126  LinearDiscriminantAnalysis        LogScaler             2       [trustLevel, quantityModificationsPerSecond]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 128  LinearDiscriminantAnalysis        LogScaler             3  [trustLevel, quantityModificationsPerScannedLi...   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                         RFE
# 82   LinearDiscriminantAnalysis   StandardScaler             1                                       [trustLevel]   {'n_components': 1, 'solver': 'svd'}                           -0.276743                                          0.011709  LinearDiscriminantAnalysis(n_components=1, pri...                 SelectKBest

# %%
# result_table.to_pickle("result_table_Linear_Discriminant_Analysis.pkl")
result_table = pd.read_pickle("result_table_Linear_Discriminant_Analysis.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# LinearDiscriminantAnalysis(n_components=1, priors=None, shrinkage=None,
#               solver='lsqr', store_covariance=False, tol=0.0001)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'valuePerSecond' 'lineItemVoidsPerPosition'
#  'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem'
#  'quantityModificationsPerSecond']
# {'n_components': 1, 'solver': 'lsqr'}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1774
# False positive:  1
# False negative:  60
# True positive:  44
# -105 for 1879 instances in the test set
# -0.05588078765300692 per instance in the test set
