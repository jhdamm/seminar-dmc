# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %%
def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score

# %% [markdown]
# # Model factory

# %%
from sklearn.tree import ExtraTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble.forest import ExtraTreesClassifier
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


model_tuning_factory = [
GridSearchCV(AdaBoostClassifier(),
                 dict(n_estimators = [20, 50,100, 150, 200],
                      algorithm = ['SAMME', 'SAMME.R'],
                      base_estimator = [DecisionTreeClassifier(max_depth=1), # default setting
                                        LogisticRegression(),
                                        ExtraTreesClassifier(),
                              #          GradientBoostingClassifier(), # takes a long time (-> + 30 sec)
                              #          RandomForestClassifier(),  # takes a long time (-> + 30 sec)
                                        DecisionTreeClassifier(),
                                        ExtraTreeClassifier(),
                                        None] # default
                      ),
                 cv = skf,
                 scoring = my_custom_score,
                 refit = True,
                 n_jobs = -1)
]   

iterations = 100     

model_tuning_factory_randomized = [
RandomizedSearchCV(AdaBoostClassifier(),
                 dict(n_estimators = [20, 50,100, 150, 200],
                      algorithm = ['SAMME', 'SAMME.R'],
                      base_estimator = [DecisionTreeClassifier(max_depth=1), # default setting
                                        LogisticRegression(),
                                        ExtraTreesClassifier(),
                              #          GradientBoostingClassifier(), # takes a long time (-> + 30 sec)
                              #          RandomForestClassifier(),  # takes a long time (-> + 30 sec)
                                        DecisionTreeClassifier(),
                                        ExtraTreeClassifier(),
                                        None] # default
                      ),
                 cv = skf,
                 scoring = my_custom_score,
                 refit = True,
                 n_iter  = iterations,
                 n_jobs = -1)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Feature Selection Technique", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished AdaBoostClassifier with No Scaling and 1 features after 65.25 seconds
# Finished AdaBoostClassifier with No Scaling and 2 features after 381.38 seconds
# Finished AdaBoostClassifier with No Scaling and 3 features after 248.67 seconds
# Finished AdaBoostClassifier with No Scaling and 4 features after 269.75 seconds
# Finished AdaBoostClassifier with No Scaling and 5 features after 165.2 seconds
# Finished AdaBoostClassifier with No Scaling and 6 features after 87.95 seconds
# Finished AdaBoostClassifier with No Scaling and 7 features after 26.19 seconds
# Finished AdaBoostClassifier with No Scaling and 8 features after 37.59 seconds
# Finished AdaBoostClassifier with No Scaling and 9 features after 26.65 seconds
# Finished AdaBoostClassifier with No Scaling and 10 features after 26.54 seconds
# Finished AdaBoostClassifier with No Scaling and 11 features after 26.59 seconds
# Finished AdaBoostClassifier with No Scaling and 12 features after 28.11 seconds
# Finished AdaBoostClassifier with No Scaling and 13 features after 27.18 seconds
# Finished AdaBoostClassifier with No Scaling and 14 features after 42.02 seconds
# Finished AdaBoostClassifier with No Scaling and 15 features after 35.29 seconds
# Finished AdaBoostClassifier with No Scaling and 16 features after 38.32 seconds
# Finished AdaBoostClassifier with No Scaling and 17 features after 33.83 seconds
# Finished AdaBoostClassifier with No Scaling and 18 features after 34.86 seconds
# Finished AdaBoostClassifier with No Scaling and 19 features after 46.54 seconds
# Finished AdaBoostClassifier with No Scaling and 20 features after 42.97 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 1 features after 70.81 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 2 features after 65.44 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 3 features after 24.27 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 4 features after 20.55 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 5 features after 32.76 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 6 features after 30.71 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 7 features after 24.81 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 8 features after 35.45 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 9 features after 35.29 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 10 features after 25.56 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 11 features after 41.39 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 12 features after 37.85 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 13 features after 31.16 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 14 features after 29.99 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 15 features after 31.62 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 16 features after 36.6 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 17 features after 27.82 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 18 features after 41.88 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 19 features after 38.45 seconds
# Finished AdaBoostClassifier with MinMaxScaler and 20 features after 45.14 seconds
# Finished AdaBoostClassifier with StandardScaler and 1 features after 89.06 seconds
# Finished AdaBoostClassifier with StandardScaler and 2 features after 63.92 seconds
# Finished AdaBoostClassifier with StandardScaler and 3 features after 16.96 seconds
# Finished AdaBoostClassifier with StandardScaler and 4 features after 23.01 seconds
# Finished AdaBoostClassifier with StandardScaler and 5 features after 20.18 seconds
# Finished AdaBoostClassifier with StandardScaler and 6 features after 25.45 seconds
# Finished AdaBoostClassifier with StandardScaler and 7 features after 22.23 seconds
# Finished AdaBoostClassifier with StandardScaler and 8 features after 30.61 seconds
# Finished AdaBoostClassifier with StandardScaler and 9 features after 28.19 seconds
# Finished AdaBoostClassifier with StandardScaler and 10 features after 41.96 seconds
# Finished AdaBoostClassifier with StandardScaler and 11 features after 26.89 seconds
# Finished AdaBoostClassifier with StandardScaler and 12 features after 37.65 seconds
# Finished AdaBoostClassifier with StandardScaler and 13 features after 34.32 seconds
# Finished AdaBoostClassifier with StandardScaler and 14 features after 36.68 seconds
# Finished AdaBoostClassifier with StandardScaler and 15 features after 41.97 seconds
# Finished AdaBoostClassifier with StandardScaler and 16 features after 35.57 seconds
# Finished AdaBoostClassifier with StandardScaler and 17 features after 57.19 seconds
# Finished AdaBoostClassifier with StandardScaler and 18 features after 31.52 seconds
# Finished AdaBoostClassifier with StandardScaler and 19 features after 37.45 seconds
# Finished AdaBoostClassifier with StandardScaler and 20 features after 44.34 seconds
# Finished AdaBoostClassifier with LogScaler and 1 features after 66.82 seconds
# Finished AdaBoostClassifier with LogScaler and 2 features after 65.46 seconds
# Finished AdaBoostClassifier with LogScaler and 3 features after 18.68 seconds
# Finished AdaBoostClassifier with LogScaler and 4 features after 25.06 seconds
# Finished AdaBoostClassifier with LogScaler and 5 features after 25.64 seconds
# Finished AdaBoostClassifier with LogScaler and 6 features after 18.72 seconds
# Finished AdaBoostClassifier with LogScaler and 7 features after 28.21 seconds
# Finished AdaBoostClassifier with LogScaler and 8 features after 25.82 seconds
# Finished AdaBoostClassifier with LogScaler and 9 features after 22.16 seconds
# Finished AdaBoostClassifier with LogScaler and 10 features after 22.64 seconds
# Finished AdaBoostClassifier with LogScaler and 11 features after 31.54 seconds
# Finished AdaBoostClassifier with LogScaler and 12 features after 25.15 seconds
# Finished AdaBoostClassifier with LogScaler and 13 features after 35.09 seconds
# Finished AdaBoostClassifier with LogScaler and 14 features after 34.21 seconds
# Finished AdaBoostClassifier with LogScaler and 15 features after 36.43 seconds
# Finished AdaBoostClassifier with LogScaler and 16 features after 47.23 seconds
# Finished AdaBoostClassifier with LogScaler and 17 features after 47.21 seconds
# Finished AdaBoostClassifier with LogScaler and 18 features after 46.88 seconds
# Finished AdaBoostClassifier with LogScaler and 19 features after 30.87 seconds
# Finished AdaBoostClassifier with LogScaler and 20 features after 51.03 seconds
#                   Model Data Preparation Feature Count Feature Selection Technique                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 95   AdaBoostClassifier   StandardScaler             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 54   AdaBoostClassifier     MinMaxScaler             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 13   AdaBoostClassifier       No Scaling             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 136  AdaBoostClassifier        LogScaler             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 11   AdaBoostClassifier       No Scaling             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 52   AdaBoostClassifier     MinMaxScaler             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 93   AdaBoostClassifier   StandardScaler             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 134  AdaBoostClassifier        LogScaler             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 107  AdaBoostClassifier   StandardScaler            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 25   AdaBoostClassifier       No Scaling            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 148  AdaBoostClassifier        LogScaler            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 66   AdaBoostClassifier     MinMaxScaler            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 116  AdaBoostClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 75   AdaBoostClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 155  AdaBoostClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 50   AdaBoostClassifier     MinMaxScaler             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 153  AdaBoostClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 91   AdaBoostClassifier   StandardScaler             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 34   AdaBoostClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 157  AdaBoostClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 147  AdaBoostClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 149  AdaBoostClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 9    AdaBoostClassifier       No Scaling             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 132  AdaBoostClassifier        LogScaler             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 151  AdaBoostClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 100  AdaBoostClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 145  AdaBoostClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 143  AdaBoostClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 18   AdaBoostClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 59   AdaBoostClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 62   AdaBoostClassifier     MinMaxScaler            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 105  AdaBoostClassifier   StandardScaler            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 64   AdaBoostClassifier     MinMaxScaler            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 146  AdaBoostClassifier        LogScaler            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 68   AdaBoostClassifier     MinMaxScaler            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 70   AdaBoostClassifier     MinMaxScaler            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 117  AdaBoostClassifier   StandardScaler            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 72   AdaBoostClassifier     MinMaxScaler            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 144  AdaBoostClassifier        LogScaler            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 120  AdaBoostClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 141  AdaBoostClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.101856  (DecisionTreeClassifier(class_weight=None, cri...
# 121  AdaBoostClassifier   StandardScaler            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 76   AdaBoostClassifier     MinMaxScaler            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 77   AdaBoostClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 115  AdaBoostClassifier   StandardScaler            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 78   AdaBoostClassifier     MinMaxScaler            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 79   AdaBoostClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 80   AdaBoostClassifier     MinMaxScaler            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 81   AdaBoostClassifier     MinMaxScaler            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 156  AdaBoostClassifier        LogScaler            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 118  AdaBoostClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 154  AdaBoostClassifier        LogScaler            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 150  AdaBoostClassifier        LogScaler            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 113  AdaBoostClassifier   StandardScaler            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 152  AdaBoostClassifier        LogScaler            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 122  AdaBoostClassifier   StandardScaler            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 111  AdaBoostClassifier   StandardScaler            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 109  AdaBoostClassifier   StandardScaler            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 103  AdaBoostClassifier   StandardScaler            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 119  AdaBoostClassifier   StandardScaler            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 163  AdaBoostClassifier        LogScaler            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 74   AdaBoostClassifier     MinMaxScaler            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 159  AdaBoostClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 158  AdaBoostClassifier        LogScaler            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 40   AdaBoostClassifier       No Scaling            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 39   AdaBoostClassifier       No Scaling            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 38   AdaBoostClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 37   AdaBoostClassifier       No Scaling            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 36   AdaBoostClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 35   AdaBoostClassifier       No Scaling            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 33   AdaBoostClassifier       No Scaling            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 160  AdaBoostClassifier        LogScaler            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 31   AdaBoostClassifier       No Scaling            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 29   AdaBoostClassifier       No Scaling            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 27   AdaBoostClassifier       No Scaling            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 23   AdaBoostClassifier       No Scaling            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 21   AdaBoostClassifier       No Scaling            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 161  AdaBoostClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 162  AdaBoostClassifier        LogScaler            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 20   AdaBoostClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.141032                                          0.063942  (DecisionTreeClassifier(class_weight=None, cri...
# 102  AdaBoostClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.141032                                          0.063942  (DecisionTreeClassifier(class_weight=None, cri...
# 61   AdaBoostClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.141032                                          0.063942  (DecisionTreeClassifier(class_weight=None, cri...
# 26   AdaBoostClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 56   AdaBoostClassifier     MinMaxScaler             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 106  AdaBoostClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 30   AdaBoostClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 108  AdaBoostClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 69   AdaBoostClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 110  AdaBoostClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 28   AdaBoostClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 112  AdaBoostClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 114  AdaBoostClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.104727  (DecisionTreeClassifier(class_weight=None, cri...
# 71   AdaBoostClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 24   AdaBoostClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 67   AdaBoostClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 22   AdaBoostClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 65   AdaBoostClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 15   AdaBoostClassifier       No Scaling             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 138  AdaBoostClassifier        LogScaler             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 63   AdaBoostClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 32   AdaBoostClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.104727  (DecisionTreeClassifier(class_weight=None, cri...
# 104  AdaBoostClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 97   AdaBoostClassifier   StandardScaler             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 73   AdaBoostClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.104727  (DecisionTreeClassifier(class_weight=None, cri...
# 101  AdaBoostClassifier   StandardScaler            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 140  AdaBoostClassifier        LogScaler             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 58   AdaBoostClassifier     MinMaxScaler             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 19   AdaBoostClassifier       No Scaling            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 17   AdaBoostClassifier       No Scaling             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 142  AdaBoostClassifier        LogScaler            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 60   AdaBoostClassifier     MinMaxScaler            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 99   AdaBoostClassifier   StandardScaler             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 139  AdaBoostClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.125067                                          0.120170  (DecisionTreeClassifier(class_weight=None, cri...
# 137  AdaBoostClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.125067                                          0.120170  (DecisionTreeClassifier(class_weight=None, cri...
# 57   AdaBoostClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.109101                                          0.082864  (DecisionTreeClassifier(class_weight=None, cri...
# 98   AdaBoostClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.109101                                          0.082864  (DecisionTreeClassifier(class_weight=None, cri...
# 16   AdaBoostClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.109101                                          0.082864  (DecisionTreeClassifier(class_weight=None, cri...
# 55   AdaBoostClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.103779                                          0.107450  (DecisionTreeClassifier(class_weight=None, cri...
# 96   AdaBoostClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.103779                                          0.107450  (DecisionTreeClassifier(class_weight=None, cri...
# 14   AdaBoostClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.103779                                          0.107450  (DecisionTreeClassifier(class_weight=None, cri...
# 94   AdaBoostClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 53   AdaBoostClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 135  AdaBoostClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 12   AdaBoostClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 48   AdaBoostClassifier     MinMaxScaler             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 89   AdaBoostClassifier   StandardScaler             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 7    AdaBoostClassifier       No Scaling             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 130  AdaBoostClassifier        LogScaler             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 92   AdaBoostClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Extra...                            0.029271                                          0.114301  ((ExtraTreeClassifier(class_weight=None, crite...
# 51   AdaBoostClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Ext...                            0.007983                                          0.215439  ((ExtraTreeClassifier(class_weight=None, crite...
# 10   AdaBoostClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Ext...                            0.007983                                          0.115178  ((ExtraTreeClassifier(class_weight=None, crite...
# 4    AdaBoostClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.007983                                          0.151929  (DecisionTreeClassifier(class_weight=None, cri...
# 86   AdaBoostClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.007983                                          0.151929  (DecisionTreeClassifier(class_weight=None, cri...
# 45   AdaBoostClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.007983                                          0.151929  (DecisionTreeClassifier(class_weight=None, cri...
# 8    AdaBoostClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.010644                                          0.170595  (LogisticRegression(C=1.0, class_weight=None, ...
# 49   AdaBoostClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.010644                                          0.170595  (LogisticRegression(C=1.0, class_weight=None, ...
# 90   AdaBoostClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.010644                                          0.170595  (LogisticRegression(C=1.0, class_weight=None, ...
# 47   AdaBoostClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.013305                                          0.117211  (DecisionTreeClassifier(class_weight=None, cri...
# 6    AdaBoostClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.013305                                          0.117211  (DecisionTreeClassifier(class_weight=None, cri...
# 88   AdaBoostClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.013305                                          0.117211  (DecisionTreeClassifier(class_weight=None, cri...
# 133  AdaBoostClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.098457                                          0.214366  (DecisionTreeClassifier(class_weight=None, cri...
# 84   AdaBoostClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 2    AdaBoostClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 125  AdaBoostClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 131  AdaBoostClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.242631  (LogisticRegression(C=1.0, class_weight=None, ...
# 127  AdaBoostClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.218027  (LogisticRegression(C=1.0, class_weight=None, ...
# 43   AdaBoostClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 129  AdaBoostClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.156998                                          0.193424  (LogisticRegression(C=1.0, class_weight=None, ...
# 0    AdaBoostClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 128  AdaBoostClassifier        LogScaler             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 126  AdaBoostClassifier        LogScaler             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 124  AdaBoostClassifier        LogScaler             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 123  AdaBoostClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 87   AdaBoostClassifier   StandardScaler             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 85   AdaBoostClassifier   StandardScaler             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 83   AdaBoostClassifier   StandardScaler             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 1    AdaBoostClassifier       No Scaling             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 46   AdaBoostClassifier     MinMaxScaler             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 44   AdaBoostClassifier     MinMaxScaler             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 42   AdaBoostClassifier     MinMaxScaler             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 41   AdaBoostClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 5    AdaBoostClassifier       No Scaling             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 3    AdaBoostClassifier       No Scaling             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 82   AdaBoostClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#                   Model Data Preparation Feature Count Feature Selection Technique                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 95   AdaBoostClassifier   StandardScaler             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 54   AdaBoostClassifier     MinMaxScaler             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 13   AdaBoostClassifier       No Scaling             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 136  AdaBoostClassifier        LogScaler             7                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.170303                                          0.077832  (DecisionTreeClassifier(class_weight=None, cri...
# 11   AdaBoostClassifier       No Scaling             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 52   AdaBoostClassifier     MinMaxScaler             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 93   AdaBoostClassifier   StandardScaler             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 134  AdaBoostClassifier        LogScaler             6                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.167642                                          0.066132  (DecisionTreeClassifier(class_weight=None, cri...
# 107  AdaBoostClassifier   StandardScaler            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 25   AdaBoostClassifier       No Scaling            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 148  AdaBoostClassifier        LogScaler            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 66   AdaBoostClassifier     MinMaxScaler            13                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.164981                                          0.059194  (DecisionTreeClassifier(class_weight=None, cri...
# 116  AdaBoostClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 75   AdaBoostClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 155  AdaBoostClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 50   AdaBoostClassifier     MinMaxScaler             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 153  AdaBoostClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 91   AdaBoostClassifier   StandardScaler             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 34   AdaBoostClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 157  AdaBoostClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 147  AdaBoostClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 149  AdaBoostClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 9    AdaBoostClassifier       No Scaling             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 132  AdaBoostClassifier        LogScaler             5                         RFE  [trustLevel, lineItemVoids, scansWithoutRegist...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.097959  (DecisionTreeClassifier(class_weight=None, cri...
# 151  AdaBoostClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.156998                                          0.070483  (DecisionTreeClassifier(class_weight=None, cri...
# 100  AdaBoostClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 145  AdaBoostClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 143  AdaBoostClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 18   AdaBoostClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 59   AdaBoostClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.146354                                          0.080961  (DecisionTreeClassifier(class_weight=None, cri...
# 62   AdaBoostClassifier     MinMaxScaler            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 105  AdaBoostClassifier   StandardScaler            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 64   AdaBoostClassifier     MinMaxScaler            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 146  AdaBoostClassifier        LogScaler            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 68   AdaBoostClassifier     MinMaxScaler            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 70   AdaBoostClassifier     MinMaxScaler            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 117  AdaBoostClassifier   StandardScaler            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 72   AdaBoostClassifier     MinMaxScaler            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 144  AdaBoostClassifier        LogScaler            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 120  AdaBoostClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 141  AdaBoostClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.101856  (DecisionTreeClassifier(class_weight=None, cri...
# 121  AdaBoostClassifier   StandardScaler            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 76   AdaBoostClassifier     MinMaxScaler            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 77   AdaBoostClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 115  AdaBoostClassifier   StandardScaler            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 78   AdaBoostClassifier     MinMaxScaler            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 79   AdaBoostClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 80   AdaBoostClassifier     MinMaxScaler            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 81   AdaBoostClassifier     MinMaxScaler            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 156  AdaBoostClassifier        LogScaler            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 118  AdaBoostClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 154  AdaBoostClassifier        LogScaler            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 150  AdaBoostClassifier        LogScaler            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 113  AdaBoostClassifier   StandardScaler            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 152  AdaBoostClassifier        LogScaler            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 122  AdaBoostClassifier   StandardScaler            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 111  AdaBoostClassifier   StandardScaler            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 109  AdaBoostClassifier   StandardScaler            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 103  AdaBoostClassifier   StandardScaler            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 119  AdaBoostClassifier   StandardScaler            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 163  AdaBoostClassifier        LogScaler            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 74   AdaBoostClassifier     MinMaxScaler            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 159  AdaBoostClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 158  AdaBoostClassifier        LogScaler            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 40   AdaBoostClassifier       No Scaling            20                       RFECV  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 39   AdaBoostClassifier       No Scaling            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 38   AdaBoostClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 37   AdaBoostClassifier       No Scaling            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 36   AdaBoostClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 35   AdaBoostClassifier       No Scaling            18                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 33   AdaBoostClassifier       No Scaling            17                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 160  AdaBoostClassifier        LogScaler            19                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 31   AdaBoostClassifier       No Scaling            16                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 29   AdaBoostClassifier       No Scaling            15                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 27   AdaBoostClassifier       No Scaling            14                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 23   AdaBoostClassifier       No Scaling            12                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 21   AdaBoostClassifier       No Scaling            11                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.143693                                          0.075532  (DecisionTreeClassifier(class_weight=None, cri...
# 161  AdaBoostClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 162  AdaBoostClassifier        LogScaler            20                         RFE  [trustLevel, totalScanTimeInSeconds, grandTota...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.143693                                          0.092806  (DecisionTreeClassifier(class_weight=None, cri...
# 20   AdaBoostClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.141032                                          0.063942  (DecisionTreeClassifier(class_weight=None, cri...
# 102  AdaBoostClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.141032                                          0.063942  (DecisionTreeClassifier(class_weight=None, cri...
# 61   AdaBoostClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.141032                                          0.063942  (DecisionTreeClassifier(class_weight=None, cri...
# 26   AdaBoostClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 56   AdaBoostClassifier     MinMaxScaler             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 106  AdaBoostClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 30   AdaBoostClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 108  AdaBoostClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 69   AdaBoostClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 110  AdaBoostClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 28   AdaBoostClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 112  AdaBoostClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 114  AdaBoostClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.104727  (DecisionTreeClassifier(class_weight=None, cri...
# 71   AdaBoostClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 24   AdaBoostClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 67   AdaBoostClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 22   AdaBoostClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 65   AdaBoostClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 15   AdaBoostClassifier       No Scaling             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 138  AdaBoostClassifier        LogScaler             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 63   AdaBoostClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 32   AdaBoostClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.104727  (DecisionTreeClassifier(class_weight=None, cri...
# 104  AdaBoostClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 97   AdaBoostClassifier   StandardScaler             8                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.093306  (DecisionTreeClassifier(class_weight=None, cri...
# 73   AdaBoostClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME.R', 'base_estimator': Dec...                            0.138371                                          0.104727  (DecisionTreeClassifier(class_weight=None, cri...
# 101  AdaBoostClassifier   StandardScaler            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 140  AdaBoostClassifier        LogScaler             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 58   AdaBoostClassifier     MinMaxScaler             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 19   AdaBoostClassifier       No Scaling            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 17   AdaBoostClassifier       No Scaling             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 142  AdaBoostClassifier        LogScaler            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 60   AdaBoostClassifier     MinMaxScaler            10                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.076189  (DecisionTreeClassifier(class_weight=None, cri...
# 99   AdaBoostClassifier   StandardScaler             9                         RFE  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.133049                                          0.088301  (DecisionTreeClassifier(class_weight=None, cri...
# 139  AdaBoostClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.125067                                          0.120170  (DecisionTreeClassifier(class_weight=None, cri...
# 137  AdaBoostClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.125067                                          0.120170  (DecisionTreeClassifier(class_weight=None, cri...
# 57   AdaBoostClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.109101                                          0.082864  (DecisionTreeClassifier(class_weight=None, cri...
# 98   AdaBoostClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.109101                                          0.082864  (DecisionTreeClassifier(class_weight=None, cri...
# 16   AdaBoostClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.109101                                          0.082864  (DecisionTreeClassifier(class_weight=None, cri...
# 55   AdaBoostClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.103779                                          0.107450  (DecisionTreeClassifier(class_weight=None, cri...
# 96   AdaBoostClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.103779                                          0.107450  (DecisionTreeClassifier(class_weight=None, cri...
# 14   AdaBoostClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.103779                                          0.107450  (DecisionTreeClassifier(class_weight=None, cri...
# 94   AdaBoostClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 53   AdaBoostClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 135  AdaBoostClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 12   AdaBoostClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.095796                                          0.112995  (DecisionTreeClassifier(class_weight=None, cri...
# 48   AdaBoostClassifier     MinMaxScaler             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 89   AdaBoostClassifier   StandardScaler             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 7    AdaBoostClassifier       No Scaling             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 130  AdaBoostClassifier        LogScaler             4                         RFE  [trustLevel, scansWithoutRegistration, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                            0.042576                                          0.179097  (DecisionTreeClassifier(class_weight=None, cri...
# 92   AdaBoostClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Extra...                            0.029271                                          0.114301  ((ExtraTreeClassifier(class_weight=None, crite...
# 51   AdaBoostClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Ext...                            0.007983                                          0.215439  ((ExtraTreeClassifier(class_weight=None, crite...
# 10   AdaBoostClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Ext...                            0.007983                                          0.115178  ((ExtraTreeClassifier(class_weight=None, crite...
# 4    AdaBoostClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.007983                                          0.151929  (DecisionTreeClassifier(class_weight=None, cri...
# 86   AdaBoostClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.007983                                          0.151929  (DecisionTreeClassifier(class_weight=None, cri...
# 45   AdaBoostClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.007983                                          0.151929  (DecisionTreeClassifier(class_weight=None, cri...
# 8    AdaBoostClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.010644                                          0.170595  (LogisticRegression(C=1.0, class_weight=None, ...
# 49   AdaBoostClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.010644                                          0.170595  (LogisticRegression(C=1.0, class_weight=None, ...
# 90   AdaBoostClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.010644                                          0.170595  (LogisticRegression(C=1.0, class_weight=None, ...
# 47   AdaBoostClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.013305                                          0.117211  (DecisionTreeClassifier(class_weight=None, cri...
# 6    AdaBoostClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.013305                                          0.117211  (DecisionTreeClassifier(class_weight=None, cri...
# 88   AdaBoostClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.013305                                          0.117211  (DecisionTreeClassifier(class_weight=None, cri...
# 133  AdaBoostClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.098457                                          0.214366  (DecisionTreeClassifier(class_weight=None, cri...
# 84   AdaBoostClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 2    AdaBoostClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 125  AdaBoostClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 131  AdaBoostClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.242631  (LogisticRegression(C=1.0, class_weight=None, ...
# 127  AdaBoostClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.218027  (LogisticRegression(C=1.0, class_weight=None, ...
# 43   AdaBoostClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.154337                                          0.196099  (LogisticRegression(C=1.0, class_weight=None, ...
# 129  AdaBoostClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'algorithm': 'SAMME.R', 'base_estimator': Log...                           -0.156998                                          0.193424  (LogisticRegression(C=1.0, class_weight=None, ...
# 0    AdaBoostClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 128  AdaBoostClassifier        LogScaler             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 126  AdaBoostClassifier        LogScaler             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 124  AdaBoostClassifier        LogScaler             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 123  AdaBoostClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 87   AdaBoostClassifier   StandardScaler             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 85   AdaBoostClassifier   StandardScaler             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 83   AdaBoostClassifier   StandardScaler             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 1    AdaBoostClassifier       No Scaling             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 46   AdaBoostClassifier     MinMaxScaler             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 44   AdaBoostClassifier     MinMaxScaler             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 42   AdaBoostClassifier     MinMaxScaler             1                         RFE                        [scannedLineItemsPerSecond]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 41   AdaBoostClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 5    AdaBoostClassifier       No Scaling             3                         RFE  [scansWithoutRegistration, scannedLineItemsPer...  {'algorithm': 'SAMME', 'base_estimator': Logis...                           -0.276743                                          0.011709  (LogisticRegression(C=1.0, class_weight=None, ...
# 3    AdaBoostClassifier       No Scaling             2                         RFE      [scannedLineItemsPerSecond, scannedLineItems]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...
# 82   AdaBoostClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'algorithm': 'SAMME', 'base_estimator': Decis...                           -0.276743                                          0.011709  (DecisionTreeClassifier(class_weight=None, cri...

# %%
#result_table.to_pickle("result_table_AdaBoost.pkl")
result_table = pd.read_pickle("result_table_AdaBoost.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
# ['trustLevel' 'lineItemVoids' 'scansWithoutRegistration'
#  'scannedLineItemsPerSecond' 'valuePerSecond' 'scannedLineItems'
#  'scansWithoutRegistrationPerScannedLineItem']
# {'algorithm': 'SAMME.R', 'base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'), 'n_estimators': 50}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  0
# True positive:  104
# 520 for 1879 instances in the test set
# 0.2767429483767962 per instance in the test set
