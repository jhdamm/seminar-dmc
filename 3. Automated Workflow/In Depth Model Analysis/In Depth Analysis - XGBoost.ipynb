# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=DeprecationWarning) 
warnings.simplefilter("ignore", UserWarning)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

njobs = -1

# %%
train=pd.read_csv('../../1. Task and Data/train.csv',sep='|')

# %% [markdown]
# # Feature Engineering

# %%
train['scannedLineItems'] = train['scannedLineItemsPerSecond'] * train['totalScanTimeInSeconds']
train['pricePerScannedLineItem'] = train['grandTotal'] / train['scannedLineItems']
train['scansWithoutRegistrationPerScannedLineItem'] = train['scansWithoutRegistration'] / train['scannedLineItems']
train['quantityModificationsPerScannedLineItem'] = train['quantityModifications'] / train['scannedLineItems']
train['lineItemVoidsPerSecond'] = train['lineItemVoids'] / train['totalScanTimeInSeconds']
train['scansWithoutRegistrationPerSecond'] = train['scansWithoutRegistration'] / train['totalScanTimeInSeconds']
train['quantityModificationsPerSecond'] = train['quantityModifications'] / train['totalScanTimeInSeconds']
train['secondsPerEuro'] = train['totalScanTimeInSeconds'] / train['grandTotal']
train['lineItemVoidsPerEuro'] = train['lineItemVoids'] / train['grandTotal']
train['scansWithoutRegistrationPerEuro'] = train['scansWithoutRegistration'] / train['grandTotal']
train['quantityModificationsPerEuro'] = train['quantityModifications'] / train['grandTotal']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer


def my_custom_loss_func(y_true, y_pred):
    cm = confusion_matrix(y_true,y_pred)
    tn, fp, fn, tp = cm.ravel()
    score = ((-25)*fp + (-5)*fn + 5*tp) / len(y_true)
    return (score)

my_custom_score = make_scorer(my_custom_loss_func, greater_is_better=True)

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import LeaveOneOut

skf = StratifiedKFold(n_splits=10)

# %% [markdown]
# # Model factory

# %%
from sklearn.tree import ExtraTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble.forest import ExtraTreesClassifier
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier


from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

base_score = [0.2, 0.4, 0.5, 0.6, 0.8]
learning_rate = [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3]
n_estimators = [100, 200, 300, 400, 500]
max_depth = range(2,10)

model_tuning_factory = [
    GridSearchCV(XGBClassifier(),
                 dict(objective = ['binary:logistic'],
                      eval_metric = ['error'],
                      base_score = [0.3, 0.5, 0.7],
                      learning_rate = [0.01, 0.1, 0.2, 0.3],
                      n_estimators = [10, 20, 50, 100]),
                 cv = skf,
                 scoring = my_custom_score,
                 refit = True,
                 n_jobs = -1),
    GridSearchCV(XGBClassifier(),
                 dict(objective = ['binary:logistic'],
                      eval_metric = ['error'],
                   #   base_score = [0.3, 0.5, 0.7],
                   #   learning_rate = [0.01, 0.1, 0.2, 0.3],
                      n_estimators = [10, 20, 50, 100],
                      base_estimator = [DecisionTreeClassifier(max_depth=1), # default setting for AdaBoost
                                        LogisticRegression(),
                                        ExtraTreesClassifier(),
                              #          GradientBoostingClassifier(), # takes a long time (-> + 30 sec)
                              #          RandomForestClassifier(),  # takes a long time (-> + 30 sec)
                                        DecisionTreeClassifier(),
                                        ExtraTreeClassifier(),
                                        None]),
                 cv = skf,
                 scoring = my_custom_score,
                 refit = True,
                 n_jobs = -1)
]        


iterations = 100     

model_tuning_factory_randomized = model_tuning_factory = [
    RandomizedSearchCV(XGBClassifier(),
                 dict(objective = ['binary:logistic'],
                      eval_metric = ['error'],
                      base_score = [0.3, 0.5, 0.7],
                      learning_rate = [0.01, 0.1, 0.2, 0.3],
                      n_estimators = [10, 20, 50, 100]),
                 cv = skf,
                 scoring = my_custom_score,
                 refit = True,
                 n_iter  = iterations,
                 n_jobs = -1),
    RandomizedSearchCV(XGBClassifier(),
                 dict(objective = ['binary:logistic'],
                      eval_metric = ['error'],
                   #   base_score = [0.3, 0.5, 0.7],
                   #   learning_rate = [0.01, 0.1, 0.2, 0.3],
                      n_estimators = [10, 20, 50, 100],
                      base_estimator = [DecisionTreeClassifier(max_depth=1), # default setting for AdaBoost
                                        LogisticRegression(),
                                        ExtraTreesClassifier(),
                              #          GradientBoostingClassifier(), # takes a long time (-> + 30 sec)
                              #          RandomForestClassifier(),  # takes a long time (-> + 30 sec)
                                        DecisionTreeClassifier(),
                                        ExtraTreeClassifier(),
                                        None]),
                 cv = skf,
                 scoring = my_custom_score,
                 refit = True,
                  n_iter  = iterations,
                 n_jobs = -1)
]

# %%
Y = train['fraud']
X = train.drop('fraud',axis=1)

# %%
import time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE

from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import FunctionTransformer

result_table = pd.DataFrame(columns=["Model", "Data Preparation", "Feature Count", "Feature Selection Technique", "Features", "Optimal Parameters", "Monetary Value Per Instance - Mean", "Monetary Value Per Instance - Standard Deviation", "Raw Model"])


for data_preparation_strategy in range(1,5):
    if (data_preparation_strategy == 1):  
        X_scaled = X
        data_preparation = "No Scaling"
    elif (data_preparation_strategy == 2):
        feature_scaler = MinMaxScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index) 
        data_preparation = "MinMaxScaler"
    elif (data_preparation_strategy == 3):
        feature_scaler = StandardScaler()  
        X_scaled = pd.DataFrame(feature_scaler.fit_transform(X.values), columns=X.columns, index=X.index)
        data_preparation = "StandardScaler"
    elif (data_preparation_strategy == 4):
        transformer = FunctionTransformer(np.log1p, validate=True)  
        X_scaled = pd.DataFrame(transformer.transform(X), columns=X.columns, index=X.index)
        data_preparation = "LogScaler"    

    for model in model_tuning_factory:   # replace with model_tuning_factory_randomized for faster results


        for feature_count in range(1,len(list(X))+1):

            model.seed = 42
            start_time = time.time()              


            # Solution with SelectKBest
            best_features = SelectKBest(f_classif, k=feature_count).fit(X_scaled,Y)
            best_feature_list = X.columns[best_features.get_support()]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]

            result_table = result_table.append({
             "Model": model_name, 
             "Data Preparation": data_preparation,   
             "Feature Count": feature_count,
             "Feature Selection Technique": "SelectKBest",   
             "Features": best_feature_list.values, 
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,   
             "Raw Model": model.best_estimator_
              }, ignore_index=True)


            # Solution with Recursive Feature Elimination -> only works for some models

            if (model.estimator.__class__.__name__ == 'LogisticRegression'
             or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
             or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
             or model.estimator.__class__.__name__ == 'RandomForestClassifier'
             or model.estimator.__class__.__name__ == 'BernoulliNB'
             or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
             or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
             or model.estimator.__class__.__name__ == 'Perceptron'
             or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

               # Traditional RFE
                rfe = RFE(model.estimator, n_features_to_select = feature_count)
                rfe = rfe.fit(X,Y)
                best_feature_list = np.array(list(X))[np.array(rfe.support_)]
                X_selected_features = X[best_feature_list]

                model.fit(X_selected_features,Y)  
                model_name = model.best_estimator_.__class__.__name__
                score_mean = model.cv_results_['mean_test_score'][model.best_index_]
                score_std = model.cv_results_['std_test_score'][model.best_index_]


                result_table = result_table.append({
                 "Model": model_name, 
                 "Data Preparation": data_preparation,
                 "Feature Count": feature_count,
                 "Feature Selection Technique": "RFE",
                 "Features": best_feature_list,
                 "Optimal Parameters": model.best_params_,
                 "Monetary Value Per Instance - Mean":  score_mean,
                 "Monetary Value Per Instance - Standard Deviation": score_std,  
                 "Raw Model": model.best_estimator_
                  }, ignore_index=True)

            end_time = time.time()

            print("Finished " + model.best_estimator_.__class__.__name__ + " with " + data_preparation + " and " + str(feature_count) + " features after " + str(round(end_time - start_time, 2)) + " seconds")



        if (model.estimator.__class__.__name__ == 'LogisticRegression'
         or model.estimator.__class__.__name__ == 'DecisionTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreeClassifier'
         or model.estimator.__class__.__name__ == 'ExtraTreesClassifier'
         or model.estimator.__class__.__name__ == 'RandomForestClassifier'
         or model.estimator.__class__.__name__ == 'BernoulliNB'
         or model.estimator.__class__.__name__ == 'AdaBoostClassifier'
         or model.estimator.__class__.__name__ == 'GradientBoostingClassifier'
         or model.estimator.__class__.__name__ == 'Perceptron'
         or model.estimator.__class__.__name__ == 'LinearDiscriminantAnalysis'):

            # RFE with Cross Validation -> determines the optimum feature count automatically
            rfecv = RFECV(model.estimator, cv = skf, scoring = my_custom_score)
            rfecv = rfe.fit(X,Y)
            best_feature_list = np.array(list(X))[np.array(rfecv.support_)]
            X_selected_features = X[best_feature_list]

            model.fit(X_selected_features,Y)  
            model_name = model.best_estimator_.__class__.__name__
            score_mean = model.cv_results_['mean_test_score'][model.best_index_]
            score_std = model.cv_results_['std_test_score'][model.best_index_]


            result_table = result_table.append({
             "Model": model_name,  
             "Data Preparation": data_preparation,
             "Feature Count": len(best_feature_list),
             "Feature Selection Technique": "RFECV",
             "Features": best_feature_list,
             "Optimal Parameters": model.best_params_,
             "Monetary Value Per Instance - Mean":  score_mean,
             "Monetary Value Per Instance - Standard Deviation": score_std,    
             "Raw Model": model.best_estimator_
              }, ignore_index=True)

result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
# Finished XGBClassifier with No Scaling and 1 features after 12.7 seconds
# Finished XGBClassifier with No Scaling and 2 features after 8.6 seconds
# Finished XGBClassifier with No Scaling and 3 features after 8.56 seconds
# Finished XGBClassifier with No Scaling and 4 features after 8.79 seconds
# Finished XGBClassifier with No Scaling and 5 features after 8.76 seconds
# Finished XGBClassifier with No Scaling and 6 features after 8.74 seconds
# Finished XGBClassifier with No Scaling and 7 features after 8.79 seconds
# Finished XGBClassifier with No Scaling and 8 features after 8.91 seconds
# Finished XGBClassifier with No Scaling and 9 features after 9.01 seconds
# Finished XGBClassifier with No Scaling and 10 features after 8.9 seconds
# Finished XGBClassifier with No Scaling and 11 features after 9.21 seconds
# Finished XGBClassifier with No Scaling and 12 features after 9.17 seconds
# Finished XGBClassifier with No Scaling and 13 features after 9.06 seconds
# Finished XGBClassifier with No Scaling and 14 features after 9.2 seconds
# Finished XGBClassifier with No Scaling and 15 features after 8.95 seconds
# Finished XGBClassifier with No Scaling and 16 features after 8.99 seconds
# Finished XGBClassifier with No Scaling and 17 features after 9.26 seconds
# Finished XGBClassifier with No Scaling and 18 features after 9.35 seconds
# Finished XGBClassifier with No Scaling and 19 features after 9.32 seconds
# Finished XGBClassifier with No Scaling and 20 features after 9.5 seconds
# Finished XGBClassifier with No Scaling and 1 features after 4.39 seconds
# Finished XGBClassifier with No Scaling and 2 features after 4.58 seconds
# Finished XGBClassifier with No Scaling and 3 features after 4.66 seconds
# Finished XGBClassifier with No Scaling and 4 features after 4.61 seconds
# Finished XGBClassifier with No Scaling and 5 features after 4.53 seconds
# Finished XGBClassifier with No Scaling and 6 features after 4.73 seconds
# Finished XGBClassifier with No Scaling and 7 features after 4.67 seconds
# Finished XGBClassifier with No Scaling and 8 features after 4.72 seconds
# Finished XGBClassifier with No Scaling and 9 features after 5.06 seconds
# Finished XGBClassifier with No Scaling and 10 features after 5.12 seconds
# Finished XGBClassifier with No Scaling and 11 features after 5.08 seconds
# Finished XGBClassifier with No Scaling and 12 features after 5.02 seconds
# Finished XGBClassifier with No Scaling and 13 features after 5.1 seconds
# Finished XGBClassifier with No Scaling and 14 features after 5.05 seconds
# Finished XGBClassifier with No Scaling and 15 features after 5.14 seconds
# Finished XGBClassifier with No Scaling and 16 features after 5.11 seconds
# Finished XGBClassifier with No Scaling and 17 features after 5.3 seconds
# Finished XGBClassifier with No Scaling and 18 features after 5.39 seconds
# Finished XGBClassifier with No Scaling and 19 features after 5.58 seconds
# Finished XGBClassifier with No Scaling and 20 features after 5.54 seconds
# Finished XGBClassifier with MinMaxScaler and 1 features after 8.81 seconds
# Finished XGBClassifier with MinMaxScaler and 2 features after 8.69 seconds
# Finished XGBClassifier with MinMaxScaler and 3 features after 8.79 seconds
# Finished XGBClassifier with MinMaxScaler and 4 features after 8.82 seconds
# Finished XGBClassifier with MinMaxScaler and 5 features after 8.83 seconds
# Finished XGBClassifier with MinMaxScaler and 6 features after 8.78 seconds
# Finished XGBClassifier with MinMaxScaler and 7 features after 8.89 seconds
# Finished XGBClassifier with MinMaxScaler and 8 features after 8.92 seconds
# Finished XGBClassifier with MinMaxScaler and 9 features after 9.03 seconds
# Finished XGBClassifier with MinMaxScaler and 10 features after 8.99 seconds
# Finished XGBClassifier with MinMaxScaler and 11 features after 9.16 seconds
# Finished XGBClassifier with MinMaxScaler and 12 features after 9.12 seconds
# Finished XGBClassifier with MinMaxScaler and 13 features after 8.99 seconds
# Finished XGBClassifier with MinMaxScaler and 14 features after 9.29 seconds
# Finished XGBClassifier with MinMaxScaler and 15 features after 9.07 seconds
# Finished XGBClassifier with MinMaxScaler and 16 features after 9.15 seconds
# Finished XGBClassifier with MinMaxScaler and 17 features after 10.92 seconds
# Finished XGBClassifier with MinMaxScaler and 18 features after 10.45 seconds
# Finished XGBClassifier with MinMaxScaler and 19 features after 10.14 seconds
# Finished XGBClassifier with MinMaxScaler and 20 features after 9.87 seconds
# Finished XGBClassifier with MinMaxScaler and 1 features after 4.43 seconds
# Finished XGBClassifier with MinMaxScaler and 2 features after 4.78 seconds
# Finished XGBClassifier with MinMaxScaler and 3 features after 4.87 seconds
# Finished XGBClassifier with MinMaxScaler and 4 features after 4.87 seconds
# Finished XGBClassifier with MinMaxScaler and 5 features after 4.71 seconds
# Finished XGBClassifier with MinMaxScaler and 6 features after 4.84 seconds
# Finished XGBClassifier with MinMaxScaler and 7 features after 4.86 seconds
# Finished XGBClassifier with MinMaxScaler and 8 features after 4.89 seconds
# Finished XGBClassifier with MinMaxScaler and 9 features after 5.0 seconds
# Finished XGBClassifier with MinMaxScaler and 10 features after 5.46 seconds
# Finished XGBClassifier with MinMaxScaler and 11 features after 4.92 seconds
# Finished XGBClassifier with MinMaxScaler and 12 features after 5.09 seconds
# Finished XGBClassifier with MinMaxScaler and 13 features after 5.37 seconds
# Finished XGBClassifier with MinMaxScaler and 14 features after 5.74 seconds
# Finished XGBClassifier with MinMaxScaler and 15 features after 5.35 seconds
# Finished XGBClassifier with MinMaxScaler and 16 features after 5.91 seconds
# Finished XGBClassifier with MinMaxScaler and 17 features after 5.9 seconds
# Finished XGBClassifier with MinMaxScaler and 18 features after 6.07 seconds
# Finished XGBClassifier with MinMaxScaler and 19 features after 5.97 seconds
# Finished XGBClassifier with MinMaxScaler and 20 features after 5.9 seconds
# Finished XGBClassifier with StandardScaler and 1 features after 8.77 seconds
# Finished XGBClassifier with StandardScaler and 2 features after 8.74 seconds
# Finished XGBClassifier with StandardScaler and 3 features after 9.0 seconds
# Finished XGBClassifier with StandardScaler and 4 features after 8.87 seconds
# Finished XGBClassifier with StandardScaler and 5 features after 8.87 seconds
# Finished XGBClassifier with StandardScaler and 6 features after 8.82 seconds
# Finished XGBClassifier with StandardScaler and 7 features after 9.1 seconds
# Finished XGBClassifier with StandardScaler and 8 features after 9.04 seconds
# Finished XGBClassifier with StandardScaler and 9 features after 9.13 seconds
# Finished XGBClassifier with StandardScaler and 10 features after 8.98 seconds
# Finished XGBClassifier with StandardScaler and 11 features after 9.0 seconds
# Finished XGBClassifier with StandardScaler and 12 features after 9.27 seconds
# Finished XGBClassifier with StandardScaler and 13 features after 9.22 seconds
# Finished XGBClassifier with StandardScaler and 14 features after 9.15 seconds
# Finished XGBClassifier with StandardScaler and 15 features after 9.16 seconds
# Finished XGBClassifier with StandardScaler and 16 features after 9.07 seconds
# Finished XGBClassifier with StandardScaler and 17 features after 9.55 seconds
# Finished XGBClassifier with StandardScaler and 18 features after 9.37 seconds
# Finished XGBClassifier with StandardScaler and 19 features after 10.04 seconds
# Finished XGBClassifier with StandardScaler and 20 features after 10.31 seconds
# Finished XGBClassifier with StandardScaler and 1 features after 4.59 seconds
# Finished XGBClassifier with StandardScaler and 2 features after 4.65 seconds
# Finished XGBClassifier with StandardScaler and 3 features after 4.79 seconds
# Finished XGBClassifier with StandardScaler and 4 features after 4.68 seconds
# Finished XGBClassifier with StandardScaler and 5 features after 4.79 seconds
# Finished XGBClassifier with StandardScaler and 6 features after 4.96 seconds
# Finished XGBClassifier with StandardScaler and 7 features after 4.82 seconds
# Finished XGBClassifier with StandardScaler and 8 features after 4.89 seconds
# Finished XGBClassifier with StandardScaler and 9 features after 4.85 seconds
# Finished XGBClassifier with StandardScaler and 10 features after 5.55 seconds
# Finished XGBClassifier with StandardScaler and 11 features after 5.24 seconds
# Finished XGBClassifier with StandardScaler and 12 features after 5.26 seconds
# Finished XGBClassifier with StandardScaler and 13 features after 5.47 seconds
# Finished XGBClassifier with StandardScaler and 14 features after 5.42 seconds
# Finished XGBClassifier with StandardScaler and 15 features after 5.33 seconds
# Finished XGBClassifier with StandardScaler and 16 features after 5.83 seconds
# Finished XGBClassifier with StandardScaler and 17 features after 5.96 seconds
# Finished XGBClassifier with StandardScaler and 18 features after 6.23 seconds
# Finished XGBClassifier with StandardScaler and 19 features after 5.95 seconds
# Finished XGBClassifier with StandardScaler and 20 features after 5.88 seconds
# Finished XGBClassifier with LogScaler and 1 features after 8.86 seconds
# Finished XGBClassifier with LogScaler and 2 features after 8.78 seconds
# Finished XGBClassifier with LogScaler and 3 features after 8.77 seconds
# Finished XGBClassifier with LogScaler and 4 features after 8.77 seconds
# Finished XGBClassifier with LogScaler and 5 features after 9.09 seconds
# Finished XGBClassifier with LogScaler and 6 features after 8.64 seconds
# Finished XGBClassifier with LogScaler and 7 features after 8.63 seconds
# Finished XGBClassifier with LogScaler and 8 features after 8.88 seconds
# Finished XGBClassifier with LogScaler and 9 features after 8.94 seconds
# Finished XGBClassifier with LogScaler and 10 features after 9.04 seconds
# Finished XGBClassifier with LogScaler and 11 features after 9.2 seconds
# Finished XGBClassifier with LogScaler and 12 features after 9.13 seconds
# Finished XGBClassifier with LogScaler and 13 features after 9.39 seconds
# Finished XGBClassifier with LogScaler and 14 features after 9.54 seconds
# Finished XGBClassifier with LogScaler and 15 features after 9.41 seconds
# Finished XGBClassifier with LogScaler and 16 features after 9.57 seconds
# Finished XGBClassifier with LogScaler and 17 features after 9.63 seconds
# Finished XGBClassifier with LogScaler and 18 features after 9.44 seconds
# Finished XGBClassifier with LogScaler and 19 features after 9.61 seconds
# Finished XGBClassifier with LogScaler and 20 features after 9.73 seconds
# Finished XGBClassifier with LogScaler and 1 features after 4.44 seconds
# Finished XGBClassifier with LogScaler and 2 features after 4.6 seconds
# Finished XGBClassifier with LogScaler and 3 features after 4.55 seconds
# Finished XGBClassifier with LogScaler and 4 features after 4.8 seconds
# Finished XGBClassifier with LogScaler and 5 features after 4.62 seconds
# Finished XGBClassifier with LogScaler and 6 features after 4.82 seconds
# Finished XGBClassifier with LogScaler and 7 features after 4.94 seconds
# Finished XGBClassifier with LogScaler and 8 features after 5.03 seconds
# Finished XGBClassifier with LogScaler and 9 features after 4.95 seconds
# Finished XGBClassifier with LogScaler and 10 features after 4.73 seconds
# Finished XGBClassifier with LogScaler and 11 features after 5.44 seconds
# Finished XGBClassifier with LogScaler and 12 features after 5.82 seconds
# Finished XGBClassifier with LogScaler and 13 features after 5.09 seconds
# Finished XGBClassifier with LogScaler and 14 features after 5.5 seconds
# Finished XGBClassifier with LogScaler and 15 features after 5.13 seconds
# Finished XGBClassifier with LogScaler and 16 features after 5.36 seconds
# Finished XGBClassifier with LogScaler and 17 features after 5.67 seconds
# Finished XGBClassifier with LogScaler and 18 features after 5.49 seconds
# Finished XGBClassifier with LogScaler and 19 features after 5.82 seconds
# Finished XGBClassifier with LogScaler and 20 features after 6.05 seconds
#              Model Data Preparation Feature Count Feature Selection Technique                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 12   XGBClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.167642                                          0.103015  XGBClassifier(base_score=0.7, booster='gbtree'...
# 92   XGBClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.167642                                          0.103015  XGBClassifier(base_score=0.7, booster='gbtree'...
# 52   XGBClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.167642                                          0.103015  XGBClassifier(base_score=0.7, booster='gbtree'...
# 90   XGBClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 133  XGBClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 50   XGBClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 10   XGBClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 127  XGBClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.093421  XGBClassifier(base_score=0.7, booster='gbtree'...
# 128  XGBClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.093421  XGBClassifier(base_score=0.7, booster='gbtree'...
# 55   XGBClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 54   XGBClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 14   XGBClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 15   XGBClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 134  XGBClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.103536  XGBClassifier(base_score=0.3, booster='gbtree'...
# 94   XGBClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 95   XGBClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 131  XGBClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.154337                                          0.108848  XGBClassifier(base_score=0.7, booster='gbtree'...
# 91   XGBClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.151676                                          0.107680  XGBClassifier(base_score=0.3, booster='gbtree'...
# 51   XGBClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.151676                                          0.107680  XGBClassifier(base_score=0.3, booster='gbtree'...
# 11   XGBClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.151676                                          0.107680  XGBClassifier(base_score=0.3, booster='gbtree'...
# 13   XGBClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.098901  XGBClassifier(base_score=0.5, booster='gbtree'...
# 132  XGBClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.102981  XGBClassifier(base_score=0.7, booster='gbtree'...
# 93   XGBClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.098901  XGBClassifier(base_score=0.5, booster='gbtree'...
# 135  XGBClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.102908  XGBClassifier(base_score=0.3, booster='gbtree'...
# 53   XGBClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.098901  XGBClassifier(base_score=0.5, booster='gbtree'...
# 136  XGBClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.143693                                          0.092207  XGBClassifier(base_score=0.5, booster='gbtree'...
# 56   XGBClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 57   XGBClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 96   XGBClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 97   XGBClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 130  XGBClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 89   XGBClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 17   XGBClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 137  XGBClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 9    XGBClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 16   XGBClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 49   XGBClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 19   XGBClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 59   XGBClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 129  XGBClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.097714  XGBClassifier(base_score=0.3, booster='gbtree'...
# 99   XGBClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 139  XGBClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 18   XGBClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 98   XGBClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 58   XGBClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 138  XGBClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 79   XGBClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 78   XGBClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 159  XGBClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 70   XGBClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.103013  XGBClassifier(base_estimator=DecisionTreeClass...
# 109  XGBClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 110  XGBClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.103013  XGBClassifier(base_estimator=DecisionTreeClass...
# 150  XGBClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 158  XGBClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 29   XGBClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 30   XGBClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.103013  XGBClassifier(base_estimator=DecisionTreeClass...
# 119  XGBClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 118  XGBClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 69   XGBClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 38   XGBClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 39   XGBClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 35   XGBClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 115  XGBClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 114  XGBClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 75   XGBClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 74   XGBClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 34   XGBClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 154  XGBClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.117084                                          0.098151  XGBClassifier(base_estimator=DecisionTreeClass...
# 116  XGBClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.114423                                          0.124175  XGBClassifier(base_estimator=DecisionTreeClass...
# 76   XGBClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.114423                                          0.124175  XGBClassifier(base_estimator=DecisionTreeClass...
# 36   XGBClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.114423                                          0.124175  XGBClassifier(base_estimator=DecisionTreeClass...
# 88   XGBClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.111762                                          0.115355  XGBClassifier(base_score=0.5, booster='gbtree'...
# 48   XGBClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.111762                                          0.115355  XGBClassifier(base_score=0.5, booster='gbtree'...
# 8    XGBClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.111762                                          0.115355  XGBClassifier(base_score=0.5, booster='gbtree'...
# 72   XGBClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.109101                                          0.122643  XGBClassifier(base_estimator=DecisionTreeClass...
# 112  XGBClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.109101                                          0.122643  XGBClassifier(base_estimator=DecisionTreeClass...
# 32   XGBClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.109101                                          0.122643  XGBClassifier(base_estimator=DecisionTreeClass...
# 113  XGBClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.125910  XGBClassifier(base_estimator=DecisionTreeClass...
# 33   XGBClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.125910  XGBClassifier(base_estimator=DecisionTreeClass...
# 149  XGBClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.138594  XGBClassifier(base_estimator=DecisionTreeClass...
# 73   XGBClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.125910  XGBClassifier(base_estimator=DecisionTreeClass...
# 31   XGBClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.122621  XGBClassifier(base_estimator=DecisionTreeClass...
# 71   XGBClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.122621  XGBClassifier(base_estimator=DecisionTreeClass...
# 155  XGBClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.119795  XGBClassifier(base_estimator=DecisionTreeClass...
# 111  XGBClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.122621  XGBClassifier(base_estimator=DecisionTreeClass...
# 156  XGBClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.144052  XGBClassifier(base_estimator=DecisionTreeClass...
# 117  XGBClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 37   XGBClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 157  XGBClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 151  XGBClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.106933  XGBClassifier(base_estimator=DecisionTreeClass...
# 152  XGBClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.146462  XGBClassifier(base_estimator=DecisionTreeClass...
# 77   XGBClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 148  XGBClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'objective': 'binary:logistic', 'n_estimators...                            0.098457                                          0.130851  XGBClassifier(base_estimator=DecisionTreeClass...
# 147  XGBClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.098457                                          0.130851  XGBClassifier(base_estimator=DecisionTreeClass...
# 7    XGBClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.095796                                          0.134228  XGBClassifier(base_score=0.3, booster='gbtree'...
# 87   XGBClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.095796                                          0.134228  XGBClassifier(base_score=0.3, booster='gbtree'...
# 47   XGBClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.095796                                          0.134228  XGBClassifier(base_score=0.3, booster='gbtree'...
# 27   XGBClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.087813                                          0.076220  XGBClassifier(base_estimator=DecisionTreeClass...
# 107  XGBClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.087813                                          0.076220  XGBClassifier(base_estimator=DecisionTreeClass...
# 67   XGBClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.087813                                          0.076220  XGBClassifier(base_estimator=DecisionTreeClass...
# 153  XGBClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.077169                                          0.127757  XGBClassifier(base_estimator=DecisionTreeClass...
# 86   XGBClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 6    XGBClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 126  XGBClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 46   XGBClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 28   XGBClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.061203                                          0.113999  XGBClassifier(base_estimator=DecisionTreeClass...
# 108  XGBClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.061203                                          0.113999  XGBClassifier(base_estimator=DecisionTreeClass...
# 68   XGBClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.061203                                          0.113999  XGBClassifier(base_estimator=DecisionTreeClass...
# 106  XGBClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 66   XGBClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 26   XGBClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 146  XGBClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 85   XGBClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.023949                                          0.183814  XGBClassifier(base_score=0.7, booster='gbtree'...
# 45   XGBClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.023949                                          0.183814  XGBClassifier(base_score=0.7, booster='gbtree'...
# 5    XGBClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.023949                                          0.183814  XGBClassifier(base_score=0.7, booster='gbtree'...
# 43   XGBClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 44   XGBClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 4    XGBClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 3    XGBClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 84   XGBClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 83   XGBClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 103  XGBClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 64   XGBClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 104  XGBClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 63   XGBClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 24   XGBClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 23   XGBClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 105  XGBClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.007983                                          0.224363  XGBClassifier(base_estimator=DecisionTreeClass...
# 65   XGBClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.007983                                          0.224363  XGBClassifier(base_estimator=DecisionTreeClass...
# 25   XGBClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.007983                                          0.224363  XGBClassifier(base_estimator=DecisionTreeClass...
# 2    XGBClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.010644                                          0.164842  XGBClassifier(base_score=0.3, booster='gbtree'...
# 82   XGBClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.010644                                          0.164842  XGBClassifier(base_score=0.3, booster='gbtree'...
# 42   XGBClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.010644                                          0.164842  XGBClassifier(base_score=0.3, booster='gbtree'...
# 62   XGBClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.018627                                          0.133467  XGBClassifier(base_estimator=DecisionTreeClass...
# 102  XGBClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.018627                                          0.133467  XGBClassifier(base_estimator=DecisionTreeClass...
# 22   XGBClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.018627                                          0.133467  XGBClassifier(base_estimator=DecisionTreeClass...
# 125  XGBClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.090474                                          0.207319  XGBClassifier(base_score=0.5, booster='gbtree'...
# 145  XGBClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.090474                                          0.207319  XGBClassifier(base_estimator=DecisionTreeClass...
# 124  XGBClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.146354                                          0.212418  XGBClassifier(base_score=0.3, booster='gbtree'...
# 123  XGBClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.149015                                          0.217050  XGBClassifier(base_score=0.5, booster='gbtree'...
# 122  XGBClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.149015                                          0.217050  XGBClassifier(base_score=0.5, booster='gbtree'...
# 21   XGBClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 1    XGBClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 101  XGBClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 41   XGBClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 81   XGBClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 121  XGBClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 141  XGBClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 61   XGBClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 144  XGBClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.164981                                          0.203795  XGBClassifier(base_estimator=DecisionTreeClass...
# 142  XGBClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.164981                                          0.203795  XGBClassifier(base_estimator=DecisionTreeClass...
# 143  XGBClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.164981                                          0.203795  XGBClassifier(base_estimator=DecisionTreeClass...
# 0    XGBClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...
# 140  XGBClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 120  XGBClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...
# 100  XGBClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 60   XGBClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 40   XGBClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...
# 20   XGBClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 80   XGBClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...

# %%
result_table.sort_values(by = "Monetary Value Per Instance - Mean", ascending = False)
# Out:
#              Model Data Preparation Feature Count Feature Selection Technique                                           Features                                 Optimal Parameters  Monetary Value Per Instance - Mean  Monetary Value Per Instance - Standard Deviation                                          Raw Model
# 12   XGBClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.167642                                          0.103015  XGBClassifier(base_score=0.7, booster='gbtree'...
# 92   XGBClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.167642                                          0.103015  XGBClassifier(base_score=0.7, booster='gbtree'...
# 52   XGBClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.167642                                          0.103015  XGBClassifier(base_score=0.7, booster='gbtree'...
# 90   XGBClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 133  XGBClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 50   XGBClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 10   XGBClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.162320                                          0.101862  XGBClassifier(base_score=0.7, booster='gbtree'...
# 127  XGBClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.093421  XGBClassifier(base_score=0.7, booster='gbtree'...
# 128  XGBClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.093421  XGBClassifier(base_score=0.7, booster='gbtree'...
# 55   XGBClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 54   XGBClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 14   XGBClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 15   XGBClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 134  XGBClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.103536  XGBClassifier(base_score=0.3, booster='gbtree'...
# 94   XGBClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 95   XGBClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.159659                                          0.102299  XGBClassifier(base_score=0.7, booster='gbtree'...
# 131  XGBClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.154337                                          0.108848  XGBClassifier(base_score=0.7, booster='gbtree'...
# 91   XGBClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.151676                                          0.107680  XGBClassifier(base_score=0.3, booster='gbtree'...
# 51   XGBClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.151676                                          0.107680  XGBClassifier(base_score=0.3, booster='gbtree'...
# 11   XGBClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.151676                                          0.107680  XGBClassifier(base_score=0.3, booster='gbtree'...
# 13   XGBClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.098901  XGBClassifier(base_score=0.5, booster='gbtree'...
# 132  XGBClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.102981  XGBClassifier(base_score=0.7, booster='gbtree'...
# 93   XGBClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.098901  XGBClassifier(base_score=0.5, booster='gbtree'...
# 135  XGBClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.102908  XGBClassifier(base_score=0.3, booster='gbtree'...
# 53   XGBClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.149015                                          0.098901  XGBClassifier(base_score=0.5, booster='gbtree'...
# 136  XGBClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.143693                                          0.092207  XGBClassifier(base_score=0.5, booster='gbtree'...
# 56   XGBClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 57   XGBClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 96   XGBClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 97   XGBClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 130  XGBClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 89   XGBClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 17   XGBClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 137  XGBClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 9    XGBClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 16   XGBClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.094493  XGBClassifier(base_score=0.3, booster='gbtree'...
# 49   XGBClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.141032                                          0.097381  XGBClassifier(base_score=0.7, booster='gbtree'...
# 19   XGBClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 59   XGBClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 129  XGBClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.097714  XGBClassifier(base_score=0.3, booster='gbtree'...
# 99   XGBClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 139  XGBClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.135710                                          0.094756  XGBClassifier(base_score=0.7, booster='gbtree'...
# 18   XGBClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 98   XGBClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 58   XGBClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 138  XGBClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.127728                                          0.100073  XGBClassifier(base_score=0.7, booster='gbtree'...
# 79   XGBClassifier     MinMaxScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 78   XGBClassifier     MinMaxScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 159  XGBClassifier        LogScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 70   XGBClassifier     MinMaxScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.103013  XGBClassifier(base_estimator=DecisionTreeClass...
# 109  XGBClassifier   StandardScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 110  XGBClassifier   StandardScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.103013  XGBClassifier(base_estimator=DecisionTreeClass...
# 150  XGBClassifier        LogScaler            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 158  XGBClassifier        LogScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 29   XGBClassifier       No Scaling            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 30   XGBClassifier       No Scaling            11                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.103013  XGBClassifier(base_estimator=DecisionTreeClass...
# 119  XGBClassifier   StandardScaler            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 118  XGBClassifier   StandardScaler            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 69   XGBClassifier     MinMaxScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.092971  XGBClassifier(base_estimator=DecisionTreeClass...
# 38   XGBClassifier       No Scaling            19                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 39   XGBClassifier       No Scaling            20                 SelectKBest  [trustLevel, totalScanTimeInSeconds, grandTota...  {'objective': 'binary:logistic', 'n_estimators...                            0.122406                                          0.120167  XGBClassifier(base_estimator=DecisionTreeClass...
# 35   XGBClassifier       No Scaling            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 115  XGBClassifier   StandardScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 114  XGBClassifier   StandardScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 75   XGBClassifier     MinMaxScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 74   XGBClassifier     MinMaxScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 34   XGBClassifier       No Scaling            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.119745                                          0.129362  XGBClassifier(base_estimator=DecisionTreeClass...
# 154  XGBClassifier        LogScaler            15                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.117084                                          0.098151  XGBClassifier(base_estimator=DecisionTreeClass...
# 116  XGBClassifier   StandardScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.114423                                          0.124175  XGBClassifier(base_estimator=DecisionTreeClass...
# 76   XGBClassifier     MinMaxScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.114423                                          0.124175  XGBClassifier(base_estimator=DecisionTreeClass...
# 36   XGBClassifier       No Scaling            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.114423                                          0.124175  XGBClassifier(base_estimator=DecisionTreeClass...
# 88   XGBClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.111762                                          0.115355  XGBClassifier(base_score=0.5, booster='gbtree'...
# 48   XGBClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.111762                                          0.115355  XGBClassifier(base_score=0.5, booster='gbtree'...
# 8    XGBClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.111762                                          0.115355  XGBClassifier(base_score=0.5, booster='gbtree'...
# 72   XGBClassifier     MinMaxScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.109101                                          0.122643  XGBClassifier(base_estimator=DecisionTreeClass...
# 112  XGBClassifier   StandardScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.109101                                          0.122643  XGBClassifier(base_estimator=DecisionTreeClass...
# 32   XGBClassifier       No Scaling            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.109101                                          0.122643  XGBClassifier(base_estimator=DecisionTreeClass...
# 113  XGBClassifier   StandardScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.125910  XGBClassifier(base_estimator=DecisionTreeClass...
# 33   XGBClassifier       No Scaling            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.125910  XGBClassifier(base_estimator=DecisionTreeClass...
# 149  XGBClassifier        LogScaler            10                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.138594  XGBClassifier(base_estimator=DecisionTreeClass...
# 73   XGBClassifier     MinMaxScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.106440                                          0.125910  XGBClassifier(base_estimator=DecisionTreeClass...
# 31   XGBClassifier       No Scaling            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.122621  XGBClassifier(base_estimator=DecisionTreeClass...
# 71   XGBClassifier     MinMaxScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.122621  XGBClassifier(base_estimator=DecisionTreeClass...
# 155  XGBClassifier        LogScaler            16                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.119795  XGBClassifier(base_estimator=DecisionTreeClass...
# 111  XGBClassifier   StandardScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.103779                                          0.122621  XGBClassifier(base_estimator=DecisionTreeClass...
# 156  XGBClassifier        LogScaler            17                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.144052  XGBClassifier(base_estimator=DecisionTreeClass...
# 117  XGBClassifier   StandardScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 37   XGBClassifier       No Scaling            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 157  XGBClassifier        LogScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 151  XGBClassifier        LogScaler            12                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.106933  XGBClassifier(base_estimator=DecisionTreeClass...
# 152  XGBClassifier        LogScaler            13                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.146462  XGBClassifier(base_estimator=DecisionTreeClass...
# 77   XGBClassifier     MinMaxScaler            18                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.101118                                          0.153699  XGBClassifier(base_estimator=DecisionTreeClass...
# 148  XGBClassifier        LogScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, valuePerS...  {'objective': 'binary:logistic', 'n_estimators...                            0.098457                                          0.130851  XGBClassifier(base_estimator=DecisionTreeClass...
# 147  XGBClassifier        LogScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.098457                                          0.130851  XGBClassifier(base_estimator=DecisionTreeClass...
# 7    XGBClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.095796                                          0.134228  XGBClassifier(base_score=0.3, booster='gbtree'...
# 87   XGBClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.095796                                          0.134228  XGBClassifier(base_score=0.3, booster='gbtree'...
# 47   XGBClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.095796                                          0.134228  XGBClassifier(base_score=0.3, booster='gbtree'...
# 27   XGBClassifier       No Scaling             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.087813                                          0.076220  XGBClassifier(base_estimator=DecisionTreeClass...
# 107  XGBClassifier   StandardScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.087813                                          0.076220  XGBClassifier(base_estimator=DecisionTreeClass...
# 67   XGBClassifier     MinMaxScaler             8                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scansWith...  {'objective': 'binary:logistic', 'n_estimators...                            0.087813                                          0.076220  XGBClassifier(base_estimator=DecisionTreeClass...
# 153  XGBClassifier        LogScaler            14                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.077169                                          0.127757  XGBClassifier(base_estimator=DecisionTreeClass...
# 86   XGBClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 6    XGBClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 126  XGBClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 46   XGBClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.074508                                          0.180681  XGBClassifier(base_score=0.3, booster='gbtree'...
# 28   XGBClassifier       No Scaling             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.061203                                          0.113999  XGBClassifier(base_estimator=DecisionTreeClass...
# 108  XGBClassifier   StandardScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.061203                                          0.113999  XGBClassifier(base_estimator=DecisionTreeClass...
# 68   XGBClassifier     MinMaxScaler             9                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.061203                                          0.113999  XGBClassifier(base_estimator=DecisionTreeClass...
# 106  XGBClassifier   StandardScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 66   XGBClassifier     MinMaxScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 26   XGBClassifier       No Scaling             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 146  XGBClassifier        LogScaler             7                 SelectKBest  [trustLevel, totalScanTimeInSeconds, lineItemV...  {'objective': 'binary:logistic', 'n_estimators...                            0.058542                                          0.102684  XGBClassifier(base_estimator=DecisionTreeClass...
# 85   XGBClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.023949                                          0.183814  XGBClassifier(base_score=0.7, booster='gbtree'...
# 45   XGBClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.023949                                          0.183814  XGBClassifier(base_score=0.7, booster='gbtree'...
# 5    XGBClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.023949                                          0.183814  XGBClassifier(base_score=0.7, booster='gbtree'...
# 43   XGBClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 44   XGBClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 4    XGBClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 3    XGBClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 84   XGBClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 83   XGBClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                            0.005322                                          0.153546  XGBClassifier(base_score=0.3, booster='gbtree'...
# 103  XGBClassifier   StandardScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 64   XGBClassifier     MinMaxScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 104  XGBClassifier   StandardScaler             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 63   XGBClassifier     MinMaxScaler             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 24   XGBClassifier       No Scaling             5                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 23   XGBClassifier       No Scaling             4                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.005322                                          0.158952  XGBClassifier(base_estimator=DecisionTreeClass...
# 105  XGBClassifier   StandardScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.007983                                          0.224363  XGBClassifier(base_estimator=DecisionTreeClass...
# 65   XGBClassifier     MinMaxScaler             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.007983                                          0.224363  XGBClassifier(base_estimator=DecisionTreeClass...
# 25   XGBClassifier       No Scaling             6                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.007983                                          0.224363  XGBClassifier(base_estimator=DecisionTreeClass...
# 2    XGBClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.010644                                          0.164842  XGBClassifier(base_score=0.3, booster='gbtree'...
# 82   XGBClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.010644                                          0.164842  XGBClassifier(base_score=0.3, booster='gbtree'...
# 42   XGBClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.010644                                          0.164842  XGBClassifier(base_score=0.3, booster='gbtree'...
# 62   XGBClassifier     MinMaxScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.018627                                          0.133467  XGBClassifier(base_estimator=DecisionTreeClass...
# 102  XGBClassifier   StandardScaler             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.018627                                          0.133467  XGBClassifier(base_estimator=DecisionTreeClass...
# 22   XGBClassifier       No Scaling             3                 SelectKBest  [trustLevel, totalScanTimeInSeconds, scannedLi...  {'objective': 'binary:logistic', 'n_estimators...                           -0.018627                                          0.133467  XGBClassifier(base_estimator=DecisionTreeClass...
# 125  XGBClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.090474                                          0.207319  XGBClassifier(base_score=0.5, booster='gbtree'...
# 145  XGBClassifier        LogScaler             6                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.090474                                          0.207319  XGBClassifier(base_estimator=DecisionTreeClass...
# 124  XGBClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.146354                                          0.212418  XGBClassifier(base_score=0.3, booster='gbtree'...
# 123  XGBClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.149015                                          0.217050  XGBClassifier(base_score=0.5, booster='gbtree'...
# 122  XGBClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.149015                                          0.217050  XGBClassifier(base_score=0.5, booster='gbtree'...
# 21   XGBClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 1    XGBClassifier       No Scaling             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 101  XGBClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 41   XGBClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 81   XGBClassifier   StandardScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 121  XGBClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_score=0.3, booster='gbtree'...
# 141  XGBClassifier        LogScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 61   XGBClassifier     MinMaxScaler             2                 SelectKBest                     [trustLevel, scannedLineItems]  {'objective': 'binary:logistic', 'n_estimators...                           -0.159659                                          0.208667  XGBClassifier(base_estimator=DecisionTreeClass...
# 144  XGBClassifier        LogScaler             5                 SelectKBest  [trustLevel, lineItemVoidsPerPosition, scanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.164981                                          0.203795  XGBClassifier(base_estimator=DecisionTreeClass...
# 142  XGBClassifier        LogScaler             3                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.164981                                          0.203795  XGBClassifier(base_estimator=DecisionTreeClass...
# 143  XGBClassifier        LogScaler             4                 SelectKBest  [trustLevel, scannedLineItems, pricePerScanned...  {'objective': 'binary:logistic', 'n_estimators...                           -0.164981                                          0.203795  XGBClassifier(base_estimator=DecisionTreeClass...
# 0    XGBClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...
# 140  XGBClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 120  XGBClassifier        LogScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...
# 100  XGBClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 60   XGBClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 40   XGBClassifier     MinMaxScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...
# 20   XGBClassifier       No Scaling             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_estimator=DecisionTreeClass...
# 80   XGBClassifier   StandardScaler             1                 SelectKBest                                       [trustLevel]  {'objective': 'binary:logistic', 'n_estimators...                           -0.276743                                          0.011709  XGBClassifier(base_score=0.3, booster='gbtree'...

# %%
#result_table.to_pickle("result_table_XGBoost.pkl")
result_table = pd.read_pickle("result_table_XGBoost.pkl")

# %%
plt.rcParams['figure.figsize'] = (10,10)

plt.scatter(result_table["Feature Count"], result_table["Monetary Value Per Instance - Mean"])
plt.xlabel('Number of features', fontsize=16)
plt.ylabel('Monetary Value Per Instance - Mean', fontsize=16)
# Out:
# Text(0, 0.5, 'Monetary Value Per Instance - Mean')

# %%
best_model = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Raw Model"]
best_model_features = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Features"]
best_parameters = result_table.loc[result_table["Monetary Value Per Instance - Mean"].argmax()]["Optimal Parameters"]

print(best_model)
print(best_model_features)
print(best_parameters)
# Out:
# XGBClassifier(base_score=0.7, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, eval_metric='error', gamma=0, learning_rate=0.3,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=nan,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1)
# ['trustLevel' 'totalScanTimeInSeconds' 'lineItemVoids'
#  'scansWithoutRegistration' 'scannedLineItemsPerSecond' 'valuePerSecond'
#  'lineItemVoidsPerPosition' 'scannedLineItems' 'pricePerScannedLineItem'
#  'scansWithoutRegistrationPerScannedLineItem'
#  'quantityModificationsPerScannedLineItem' 'lineItemVoidsPerSecond'
#  'quantityModificationsPerSecond']
# {'objective': 'binary:logistic', 'n_estimators': 100, 'learning_rate': 0.3, 'eval_metric': 'error', 'base_score': 0.7}

# %%
from sklearn.metrics import confusion_matrix

def get_monetary_value(cm):
        tn, fp, fn, tp = cm.ravel()
        print("True negative: ", tn)
        print("False positive: ", fp)
        print("False negative: ", fn)
        print("True positive: ", tp)
        score = (-25)*fp + (-5)*fn + 5*tp
        print(str(score) + " for " + str(sum(sum(cm))) + " instances in the test set")
        print(str(score/sum(sum(cm))) + " per instance in the test set")
        return score
    
cm = confusion_matrix(Y , best_model.predict(X[best_model_features]))

monetary_value = get_monetary_value(cm)
# Out:
# True negative:  1775
# False positive:  0
# False negative:  0
# True positive:  104
# 520 for 1879 instances in the test set
# 0.2767429483767962 per instance in the test set
